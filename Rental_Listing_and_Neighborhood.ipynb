# %% [markdown]
# # Final Project - Examining scrapped data from Kijiji and RentFaster using Spark and Yelp API [Partnership with Community Data Program]
#
# **Overview**
#
# In the dynamic field of Data/ML, engaging with Application Programming Interfaces (APIs) is a common practice, enabling the extraction of data or interaction with software. Nonetheless, not all applications/services offer API so it is important to understand how to extract data even in cases where an API is not available. Similarly, adapting to various data management techniques is essential across different companies or organizations. This project centers around gathering data from rental listings within Alberta, Canada, specifically focusing on platforms such as Kijiji and RentFaster. Additionally, you will be leveraging the Yelp API, you'll identify highly rated restaurants and analyze their proximity to these rental listings you scraped from RentFaster and Kijiji.
#
# The data acquisition phase is facilitated through a pre-developed web scraper, designed to streamline the process of extracting rental listings. This initiative is in collaboration with the Community Data Program, aiming to make rental listing data within Canada more accessible to communities with limited access. Initially focusing on Alberta, this project sets the groundwork for future expansion across other regions.
#
# Your task involves determining the pertinent data to extract, followed by managing this data within a distributed system, namely Apache Spark. Subsequently, you will perform data analysis and processing utilizing Spark SQL. This final project encourages collaboration in groups of up to 3 members (you are allowed to use the same members as your midterm), where active participation from all members is expected. It's crucial to note that your presentation will constitute 30% of your overall score, highlighting the importance of both teamwork and individual effort in the successful completion of this project.
#
# **Deliverables**
#
#
# 1.  Your main jupyter notebook file with the proper execution of:
#    *  Part 1: Data Collection
#    *  Part 2: DataFrame, Tables creation and Yelp API setup
#    *  Part 3: Explore your data
# 2.  The data collected from Part 1 in CSV format (Total of 4 CSV files for both Kijiji and RentFaster)
# 3.  A presentation (done using the software of your choosing, PowerPoint, Canvas etc) where you will showcase Part 1 to 3 of your project. What we are specifically looking is the following:
#    *  Issues faced acquiring your data, this could be limitations with the web scraping procedure
#    *  Data quality issues such as missing values or difficulties when working with multiple data types and how to solve/consider those in your analysis
#    *  The highlights and correlations that you derived based on the analysis of the data, you should be able to answer the following questions:
#        * Is there a correlation between the rental price vs the quality/price of restaurants nearby?
#        * Is the data coming from Yelp of enough quality to drive insides?
#        * What would you do better or different to arrive at a more conclusive analysis?
#        * What are your next steps?
#        * Is this data pipeline you built enough to scale for big data?
#
# **Important NOTES**
#
#
# The presentation **IS NOT GOING TO BE A RECORDING**. It will be a live presentation either in-person or online where I will engage in questions with all of the team. If a member is not present, that person will lose automatically 30% of the total grade of the Final.
#
#
# *InPerson Students*
#
#
# *  The presentation will be held in-person on Monday April 22nd and Tuesday
# April 23rd (time to be decided).
#
#
# *Hyflex Students*
# *  You have the opportunity to present in-person (if you can make it) or schedule an online presentation with me. Either way you need to let me know
#
#
# **Due Date** You have until Saturday April 20th at Midnight to submit your code. But you still have time to work on your presentation as the presentation will be held on the 22th and 23th.

# %% [markdown]
# ## Web Scraping Code
# In this section you will find everything you need to know about the Scraper we have built for you to get data from rentals within AB from RentFaster and Kijiji

# %% [markdown]
# ### Working with PlayWright
#
# Playwright is a tool developed by Microsoft that allows developers to automate interactions with web browsers. In simpler terms, it can control browsers programmatically to perform tasks like navigating through web pages, clicking buttons, filling out forms, and extracting information from websites, all through a script or program.
#
# Here’s why Playwright is particularly useful for web scraping rental listings in RentFaster and Kijiji:
# 1. **Supports Multiple Browsers**: Playwright can control different browsers (like Chrome, Firefox, and Safari) using a single API. This makes it easier to scrape websites as they appear in various browsers without needing to adjust your code significantly for each one.
#
# 2. **Headless Browsing**: It can run browsers in 'headless' mode, meaning it can navigate and interact with websites without actually opening a browser window. This speeds up the scraping process and allows for running scrapers on servers or in environments where a graphical interface is not available.
#
# 3. **Automates Complex Interactions**: Some websites require complex interactions to access their data, like logging in, navigating through menus, or interacting with JavaScript. Playwright can automate these interactions, making it possible to scrape data from sites that would be difficult or impossible to scrape with simpler tools.
#
# Learn more about it! https://playwright.dev/python/docs/intro

# %%
# !pip install playwright
# !playwright install
# Out:
# Requirement already satisfied: playwright in /usr/local/lib/python3.10/dist-packages (1.43.0)
# Requirement already satisfied: greenlet==3.0.3 in /usr/local/lib/python3.10/dist-packages (from playwright) (3.0.3)
# Requirement already satisfied: pyee==11.1.0 in /usr/local/lib/python3.10/dist-packages (from playwright) (11.1.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from pyee==11.1.0->playwright) (4.11.0)
# Playwright Host validation warning:
# ╔══════════════════════════════════════════════════════╗
# ║ Host system is missing dependencies to run browsers. ║
# ║ Missing libraries:                                   ║
# ║     libwoff2dec.so.1.0.2                             ║
# ║     libgstgl-1.0.so.0                                ║
# ║     libgstcodecparsers-1.0.so.0                      ║
# ║     libharfbuzz-icu.so.0                             ║
# ║     libenchant-2.so.2                                ║
# ║     libsecret-1.so.0                                 ║
# ║     libhyphen.so.0                                   ║
# ║     libmanette-0.2.so.0                              ║
# ╚══════════════════════════════════════════════════════╝
#     at validateDependenciesLinux (/usr/local/lib/python3.10/dist-packages/playwright/driver/package/lib/server/registry/dependencies.js:216:9)
#     at process.processTicksAndRejections (node:internal/process/task_queues:95:5)
#     at async Registry._validateHostRequirements (/usr/local/lib/python3.10/dist-packages/playwright/driver/package/lib/server/registry/index.js:587:43)
#     at async Registry._validateHostRequirementsForExecutableIfNeeded (/usr/local/lib/python3.10/dist-packages/playwright/driver/package/lib/server/registry/index.js:685:7)
#     at async Registry.validateHostRequirementsForExecutablesIfNeeded (/usr/local/lib/python3.10/dist-packages/playwright/driver/package/lib/server/registry/index.js:674:43)
#     at async t.<anonymous> (/usr/local/lib/python3.10/dist-packages/playwright/driver/package/lib/cli/program.js:119:7)

# %% [markdown]
# ### Web Scraping Libraries - Explained
#
# When scraping rental listings from websites like Kijiji and RentFaster, several Python libraries will be of use in the process. Here's how each of them contributes:
#
# - **`asyncio`**: This is a library to write concurrent code using the async/await syntax. It is useful for handling asynchronous operations, making it possible to scrape websites more efficiently. When used with `playwright`, it allows for asynchronous navigation and interaction with web pages, speeding up the web scraping process by performing multiple tasks concurrently.
#
# - **`json`**: JavaScript Object Notation (JSON) is a lightweight data interchange format. This library can be used to parse JSON data that will be returned from HTML requests on rental websites and to store scraped data in a JSON format, making it easier to work with complex data structures using Spark.
#
# - **`requests`**: A powerful HTTP library for making requests to web servers. It is used to request the HTML content of web pages from Kijiji and RentFaster. `requests` is straightforward and can handle various types of HTTP requests, essential for accessing the data on rental listings.
#
# - **`time`**: This module provides various time-related functions. We will use it to handle rate limiting by adding delays between requests, ensuring that your scraping activities do not lead to your IP being banned from the website for making too many requests too quickly.
#
# - **`re` (Regular Expression)**: This library is used to search, match, or replace patterns in strings. In our web scraping process, is particularly useful for extracting specific pieces of data from HTML or text, such as phone numbers, prices, or other structured information from rental listings.
#
# - **`pandas` (pd)**: A powerful data manipulation and analysis library. After scraping the data, `pandas` can be used to clean, transform, and analyze the rental listings data, making it easier to work with large datasets and perform complex data analysis tasks.
#
# - **`csv`**: This module implements classes to read and write tabular data in CSV format. It can be used to save scraped data into CSV files, which is a common format for storing tabular data, allowing for easy sharing and analysis of the scraped rental listings.
#
# - **`BeautifulSoup` (from `bs4`)**: A library for parsing HTML and XML documents. It creates parse trees that is helpful to extract information from web pages easily. `BeautifulSoup` works well with `requests` to navigate the HTML structure of a page and extract data, such as rental prices, descriptions, and images.
#
# - **`playwright.async_api` (async_playwright, TimeoutError)**: `playwright` is a framework for browser automation and `async_playwright` refers to its asynchronous API. This is particularly useful for interacting with JavaScript-heavy websites like RentFaster, allowing for headless browser interaction, page navigation, and dynamic content loading. The `TimeoutError` helps in handling exceptions that may occur if a page takes too long to load or respond.

# %%
import asyncio
import json
import requests
import time
import re
import pandas as pd
import csv
import numpy as np
from bs4 import BeautifulSoup
# Import async playwright
from playwright.async_api import async_playwright, TimeoutError

# %% [markdown]
# ### Get HTML content from Website - PlayWright
#
# The `get_page_content` function is an asynchronous utility designed for web scraping, specifically optimized for fetching content from RentFaster and Kijiji. It employs the Playwright library to programmatically control a web browser, navigating to a specified URL and waiting for the page to load fully before capturing its HTML content. This is particularly useful for RentFaster that dynamicaly loads content asynchronously with JavaScript.
#
# The function is capable of making multiple attempts to fetch a page's content, retrying up to a predefined limit in case of timeouts, which can occur with Kijiji. This retry mechanism, coupled with the ability to wait for specific page elements to appear before proceeding, ensures reliability in the scraping process. It can specifically wait for elements that signify the page has fully loaded on either RentFaster or Kijiji, based on parameters passed to it. After successfully retrieving the page content, the browser session is closed to clean up resources. If the function fails to fetch the content after the specified number of retries, it raises an exception to signal the failure. This approach ensures robustness and flexibility in scraping tasks, accommodating the challenges posed these websites.

# %%
async def get_page_content(url, wait_rf, wait_kk, retries=5):
    attempt = 0
    while attempt < retries:
        try:
            async with async_playwright() as p:
                # Launch the browser
                browser = await p.chromium.launch()
                page = await browser.new_page()

                # Navigate to the URL
                await page.goto(url)
                if wait_rf:
                    # Wait for a selector to ensure the page has loaded (rent-faster)
                    await page.wait_for_selector('.card.my-3.p-3.ng-scope', timeout=6000)
                if wait_kk:
                    # Wait for a selector to ensure the page has loaded (kijiji)
                    await page.wait_for_selector('ul[data-testid="srp-search-list"]', timeout=6000)
                await asyncio.sleep(1)
                # Get the page content
                content = await page.content()
                # Close the browser
                await browser.close()

                return content
        except TimeoutError:
            print(f"Attempt {attempt + 1} failed, retrying...")
            attempt += 1
            if attempt < retries:
                await asyncio.sleep(2)  # Wait a bit before retrying

    # If all attempts fail, raise an exception or return a specific value
    raise Exception(f"All {retries} attempts failed.")

# %% [markdown]
# ### Retrieve URLs from listing website -   Kijiji
# The `get_urls_kk` function is an asynchronous function crafted to parse URLs from the HTML content of a Kijiji listing page, a task preceded by fetching the page content with the `get_page_content` function. Utilizing the BeautifulSoup library, the function interprets the HTML to find specific anchor (`<a>`) tags that denote listing links on Kijiji.
#
# This method is finely tuned for the structure of Kijiji's website, making use of distinct HTML attributes to precisely extract and construct URLs for each listing. It plays an essential role in web scraping workflows aimed at navigating from a general listings page to specific listings for more detailed data extraction.

# %%
async def get_urls_kk(content):
    soup = BeautifulSoup(content, 'html.parser')
    urls = []
    links = soup.find_all('a', {'data-testid': 'listing-link'}, href=True)
    for link in links:
        urls.append('https://www.kijiji.ca' + link['href'])
    return urls

# %% [markdown]
# ### Retrieve URLs from listing website - RentFaster
#
# The `get_urls_rf` function is designed to extract URLs from the HTML content of a RentFaster listing page. Unlike the previous function focused on Kijiji, this one deals with structured data embedded within a `<script>` tag in JSON format, a common technique for web developers to initialize JavaScript objects on web pages.
#
# This function highlights a different approach to web scraping, focusing on extracting data from JSON embedded within HTML content, which can be a more direct and less error-prone method than parsing the HTML structure itself, especially when the website utilizes JavaScript to render content dynamically.

# %%
back_up_details = {}
back_up_overviews = {}

def get_urls_rf(content):
    soup = BeautifulSoup(content, 'html.parser')
    script_tag = soup.find('script', id='ldjsonProperties')
    json_str = script_tag.string if script_tag else ''

    # Check if we successfully found the script tag and extracted the string
    if not json_str:
        print("JSON string not found.")
    else:
        data = json.loads(json_str)
        urls = []
        # Check if the key 'itemListElement' is in the parsed data
        if 'itemListElement' in data:
            # Iterate through each item and extract the 'url'
            for item in data['itemListElement']:
                url = item.get('url', None)
                if url:
                    urls.append(url)
        return urls

# %% [markdown]
# ### Generate URLs from both website programmatically
#
# This functions deals with creating a list of listings and their URLs for both Kijiji and RentFaster. It is designed to call the functions we defined above based on the following parameters:
#
#
# *   `parameter` : Can be the a location within Alberta if `rentfaster` is `True`, or it can be a `page` number based on which page from a listing we want to get the URLs from if `kijiji` is `True`
# *   `kijiji`: Boolean True or False
# *   `rentfaster`: Boolean True or False

# %%
async def url_generator(parameter,kijiji,rentfaster):
  contents_urls = []
  if rentfaster:
    for location in parameter:
      url = f'https://www.rentfaster.ca/ab/{location}/#dialog-listview'
      content = await get_page_content(url,True,False)
      time.sleep(1)
      print(f"Getting listing URLs for {location} [RentFaster]")
      urls = get_urls_rf(content)
      contents_urls.append(urls)
      time.sleep(1)
    print("URLs retrieved")
    return contents_urls
  elif kijiji:
    for n in range(1, len(parameter) + 1):
      url = f"https://www.kijiji.ca/b-for-rent/alberta/page-{parameter[n-1]}/c30349001l9003"
      print(f"Getting listing URLs for AB page {parameter[n-1]} [Kijiji]")
      content = await get_page_content(url, wait_rf = False, wait_kk = True)
      time.sleep(1)
      urls = await get_urls_kk(content)
      contents_urls.append(urls)
      time.sleep(1)
    print("URLs retrieved")
    return contents_urls
  else:
    print("Invalid Options")
    return None

# %% [markdown]
# ### Scraping and Parsing content from Website
# To understand the structure and dynamics of HTML content fetched from Kijiji and RentFaster is important to effectively use web scraping, especially when extracting detailed information about rental listings. This complexity arises because websites such as RentFaster often employ dynamic content loading through JavaScript, which means the data you're interested in (e.g., address, price, listing title, description, features of the listing like pet-friendliness or laundry facilities, contact info, posting date, URL) may not be present in the initial HTML served by the web server but loaded asynchronously thereafter.
#
# Given these challenges, tailored approaches are necessary for scraping each website. These functions are meticulously designed to navigate the intricacies of each site's HTML structure and JavaScript dynamics.
#
# RentFaster, for instance, stores relevant listing details within `<script>` tags in JSON format. The parsing function for RentFaster content is adept at locating these tags, extracting and decoding the JSON, and then systematically pulling out and organizing the necessary data, such as property overview, amenities, and unit details. This method hinges on the JSON being structured in a predictable manner, allowing for direct access to various pieces of information without the need to interpret the HTML visually as a browser would.
#
# On the other hand, the Kijiji content parsing function deals with a more traditional mix of HTML elements and embedded JSON scripts. It has to navigate through the document, identifying specific tags and classes to extract the listing’s description, address, and other attributes. This function also handles dynamically loaded data, requiring it to parse both the visible HTML and the JavaScript variables or window properties that contain JSON data with additional details about the listings.
#
# The need for these tailored functions arise from the variance in how each website delivers content to the end-user. While one site might embed data within HTML in a straightforward manner, another might rely heavily on JavaScript to construct the page dynamically, necessitating a flexible and nuanced approach to scraping.
#
# This project highlights a broader principle in web scraping: the importance of carefully analyzing the source content of a website to understand how it structures and delivers data. This analysis is crucial for designing efficient scrapers that can reliably extract the needed information despite the complexities of modern web development practices, including the use of JavaScript and AJAX for dynamic content loading. Such an understanding not only informs the technical strategy for data extraction but also ensures the scraper can adapt to changes in the website's structure or content delivery mechanisms over time.

# %%
# @title #### RentFaster Parser Function
def parse_json_data_rf(content, url):
    soup = BeautifulSoup(content, 'html.parser')
    script_tags = soup.find_all("script", type="application/ld+json")
    match = re.search(r'https://www\.rentfaster\.ca(/[^/]+/[^/]+)/', url)
    location = match.group(1)
    data = None
    for tag in script_tags:
        try:
            if tag.string != None:
              json_data = json.loads(tag.string)
              if 'mainEntity' in json_data:
                  data = json_data['mainEntity']
                  break
        except json.JSONDecodeError:
            continue

    if data is None:
      print("No valid JSON data found for the provided listing. Skipping Listing")
      return
    # Extract the ID from the URL
    property_id = re.search(r'(\d+)$', data.get("@id", "")).group(1) if data.get("@id") else None

    property_overview = {
        "id": property_id,
        "location": location,
        "name": data.get("name", "Undefined"),
        "url": data.get("url", "Undefined"),
        "slogan": data.get("slogan", "Undefined"),
        "priceRange": data.get("priceRange", "Undefined"),
        "telephone": data.get("telephone", "Undefined"),
        "image": data.get("image", "Undefined"),
        "description": data.get("description", "Undefined")
    }
    if "address" in data:
      address_parts = [
          data["address"].get("streetAddress", ""),
          data["address"].get("addressLocality", ""),
          data["address"].get("addressRegion", ""),
          data["address"].get("postalCode", ""),
          data["address"]["addressCountry"].get("name", "")
      ]
      # Filter out empty strings and join with a comma
      property_overview["address"] = ', '.join(filter(None, address_parts))
    else:
      property_overview["address"] = "Undefined"

    # Conditionally add amenities if they exist
    if "amenityFeature" in data:
      property_overview["amenities"] = {feature.get("name", ""): feature.get("value", "") for feature in data["amenityFeature"]}
    else:
      property_overview["amenities"] = {"Undefined"}

    # Update the global dictionary for property overviews
    all_property_overviews[property_id] = property_overview

    # Extract and restructure unit details
    unit_details = [
        {
            "property_id": property_id,  # Link to property by ID
            "unit_name": unit["name"],
            "description": unit["description"],
            "squareFeet": next((prop["value"] for prop in unit["additionalProperty"] if prop["name"] == "Square Feet"), None),
            "availabilityDate": next((prop["value"] for prop in unit["additionalProperty"] if prop["name"] == "Availability Date"), None),
            "utilitiesIncluded": next((prop["value"] for prop in unit["additionalProperty"] if prop["name"] == "Utilities Included"), None)
        } for unit in data.get("containsPlace", [])
    ]

    for unit_detail in unit_details:
        # Sanitize the unit_name to remove spaces and special characters for use as a key
        sanitized_unit_name = re.sub(r'\W+', '_', unit_detail["unit_name"])  # Replace non-word characters with underscore
        key = f'{property_id}_{sanitized_unit_name}'
        all_unit_details[key] = unit_detail

# %%
# @title #### Kijiji Parser Function
def parse_json_data_kk(content, link):

  script_content_var = None
  script_content_window = None
  match_link = re.search(r'/(\d+)$', link)
  property_id = match_link.group(1)
  soup = BeautifulSoup(content, 'html.parser')

  # Find the meta tag with the name 'description'
  description_container = soup.find('div', class_='descriptionContainer-2067035870')
  if description_container and description_container.div:
      description = description_container.div.get_text(separator='\n').strip()
  else:
      description = "Undefined"

  # Find address
  adLocation_tags = soup.find_all('span', itemprop="address")

  adLocation = {f"address_{index+1}": tag.get_text().strip()
                    for index, tag in enumerate(adLocation_tags)} if adLocation_tags else {"Undefined": "Undefined"}

  # Find date posted - Assuming this extracts the text correctly, or you might need to adjust based on actual content
  date = soup.select_one("div[class*=datePosted-1776470403]").get_text() if soup.select_one("div[class*=datePosted-1776470403]") else "Undefined"

  script_tag_var = soup.find('script', string=re.compile('var dataLayer ='))
  if script_tag_var is not None:
      script_content_var = script_tag_var.string
      match_var = re.search(r'var dataLayer = (\[.*?\]);', script_content_var, re.DOTALL)
      if match_var:
        data_layer = json.loads(match_var.group(1))
        item = data_layer[0]
        price_info = item.get('a', {}).get('prc', {})
  else:
    price_info = "Undefined"

  script_tag_window = soup.find('script', string=re.compile('window\.__data'))
  if script_tag_window is not None:
      script_content_window = script_tag_window.string
      match_window = re.search(r'window\.__data=(\{.*?\});', script_content_window, re.DOTALL)
      if match_window:
        data = json.loads(match_window.group(1))
        ad_info = data.get("config", {}).get("VIP", {})
        ad_location = ad_info.get("adLocation", {})
        ad_attributes = ad_info.get("adAttributes", {})
        attributes_dict = {}
        for attr in ad_attributes:
          label = attr['localeSpecificValues']['en']['label']
          value = attr['localeSpecificValues']['en']['value']
          attributes_dict[label] = value
  else:
    attributes_dict = "Undefined"

  all_property_overviews_kk[property_id] = {
      "listing_url": link,
      "date_posted": date,
      "address" : adLocation,
      "price_info": price_info,
      "description": description
  }
  all_unit_details_kk[property_id] = attributes_dict

# %%
# @title #### Parser based on CSV with URLs
async def scrape_urls_from_csv(filename,website):
    urls = []
    # Read URLs from CSV
    with open(filename, 'r', newline='') as csvfile:
        reader = csv.reader(csvfile)
        for row in reader:
            if row:  # Check if the row is not empty
                urls.append(row[0])
    total_urls = len(urls)
    print(f"URLs extracted from the CSV file: {filename}. Total URLs to scrape: {total_urls}")

    # Scraping loop
    for index, url in enumerate(urls, start=1):
        content = await get_page_content(str(url), wait_rf=False, wait_kk=False)
        print(f"Scraping started for {url}. [{index}/{total_urls}]")
        await asyncio.sleep(0.5)
        if website == 'kijiji':
          parse_json_data_kk(content, url)
        elif website == 'rentfaster':
          parse_json_data_rf(content, url)
        print(f"Scraped {index} urls out of {total_urls} total.")

    print("Scraping Finished")

# %% [markdown]
# ### Data Transformation Toolkit
# General functions to covert data into CSV and DataFrame

# %%
# @title #### Create csv - RentFaster/Kijiji
def convert_to_tables(all_property_overviews, all_unit_details, filename_overview, filename_details):
    # Convert dictionaries to dataframes, including the keys as a new column
    property_overviews_df = pd.DataFrame.from_dict(all_property_overviews, orient='index').reset_index()
    unit_details_df = pd.DataFrame.from_dict(all_unit_details, orient='index').reset_index()

    # Rename the 'index' column to 'property_id'
    property_overviews_df.rename(columns={'index': 'property_id'}, inplace=True)
    unit_details_df.rename(columns={'index': 'property_id'}, inplace=True)

    # Example: Save to CSV
    property_overviews_df.to_csv(filename_overview, index=False)
    unit_details_df.to_csv(filename_details, index=False)

def convert_rentfaster_to_csv(all_unit_details,all_property_overviews,csv_file_path_details,csv_file_path_overview):
    #converting details data into csv
    df_details = pd.DataFrame.from_dict(all_unit_details, orient='index').reset_index().rename(columns={'index':'unit_id'})
    df_details['description'] = df_details['description'].str.replace(',','')
    df_details['unit_name'] = df_details['unit_name'].str.replace(',','')
    df_details.to_csv(csv_file_path_details, index=False)

    #converting overview data into csv
    df_o = pd.DataFrame.from_dict(all_property_overviews, orient='index').reset_index().rename(columns={'index':'property_id'})
    df_o['description'] = df_o['description'].apply(lambda x: re.sub(r'[^A-Za-z0-9 ]+', '', x))
    df_o.to_csv(csv_file_path_overview, index=False)

def convert_kijiji_to_csv(all_unit_details,all_property_overviews,csv_file_path_details,csv_file_path_overview):
    #converting details data into csv
    df_details = pd.DataFrame.from_dict(all_unit_details, orient='index')
    df_details.to_csv(csv_file_path_details, index=False)

    #converting overview data into csv
    df_o = pd.DataFrame.from_dict(all_property_overviews, orient='index')
    df_o['description'] = df_o['description'].apply(lambda x: re.sub(r'[^A-Za-z0-9 ]+', '', x))
    df_o.to_csv(csv_file_path_overview, index=False)

# %%
# @title #### Convert list of URLs into CSV
def convert_to_csv(data, filename):
  # Open the file in write mode ('w') and create a csv.writer object
  count = 0
  with open(filename, 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    # Write each row to the CSV file
    for list_ in data:
      for link in list_:
        count += 1
        writer.writerow([link])

  print(f"CSV file '{filename}' created successfully. Number of Links: {count}")

# %% [markdown]
# ## Part 1: Getting your datasets from Web Scraping [Data Collection - Total 20 pts]
#
#
# **Objective**: Create 4 CSVs on the data scraped from Kijiji and RentFaster.
#
# For RentFaster, we have selected all cities/areas from AB. We can expand the search and include more provinces as need it but not required. You can select up to 25 locations across Alberta to get the listing data from Rent Faster.
#
# For Kijiji, we will be selecting listings from the following [URL](https://www.kijiji.ca/b-for-rent/alberta/page-1/c30349001l9003) and you can pick the number of listing pages you want to scrape links from. The total listing pages are 190. Each page contains 40 listings so you can get up to 7600 URLs from the website, but you are not required to get all the data.
#
#
# In order to get the 20 pts from this step you will need to perform the following:
#
# *   Select 1 major city (either Edmonton or Calgary) + 5 other locations. The total selected cities/areas need to be 6, which will be approximately 600+ listings. This can be done in **Step 1**
# *   Select 1 or up to 3 page ranges from **Step 2**. The total numbers generated by the ranges you picked CANNOT be more than 12. Here is an example of a proper range selection:
#
#     * range 1 = [20 - 25], range 2 = [9 - 11], range 3 = [3 - 5] -> Numbers generated [3, 4, 5, 9, 10, 11, 20, 21, 22, 23, 24, 25] Total of 12 page numbers
# *   Run cells from Step 3 to 9 to generate the CSVs from the data you scraped and follow the instructions

# %%
# @title ### Step 1: Alberta Location Selector - RentFaster
from ipywidgets import SelectMultiple, VBox, Label, Layout, Text
import ipywidgets as widgets

# Define your list of options for the multiple select widget
options = [
  'edmonton', 'calgary', 'cochrane', 'red-deer', 'fort-mcmurray',
  'airdrie', 'wetaskiwin', 'lethbridge', 'camrose', 'spruce-grove',
  'okotoks', 'chestermere', 'bonnyville', 'st-albert', 'sylvan-lake',
  'beaumont', 'morinville', 'leduc', 'grande-prairie', 'peace-river',
  'strathmore', 'edson', 'wainwright', 'olds','ponoka'
]

# Create a text widget for displaying selected options
selected_output = Text(
    value='',
    placeholder='Selected options will appear here',
    description='Selected:',
    disabled=False,
    layout=Layout(width='100%')
)

# Event handler function
def on_selection_change(change):
    if change['name'] == 'value':
        # Convert selected options to lowercase and update the text widget
        selected_options = ', '.join([option.lower() for option in change['new']])
        selected_output.value = selected_options

# Create the SelectMultiple widget
location_selector = SelectMultiple(
    options=options,
    value=[],  # No default selection
    description='Locations',
    disabled=False,
    layout=Layout(width='100%', height='200px')  # Adjust layout as needed
)

# Set up the event handler for changes in selection
location_selector.observe(on_selection_change, names='value')

# Instructions on how to select multiple options
instructions = Label('Hold down "Ctrl" (Windows/Linux) or "Cmd" (Mac) to select multiple locations.')

# Group the instructions, the select widget, and the selected output together
vbox = VBox([instructions, location_selector, selected_output])
display(vbox)
# Out:
# VBox(children=(Label(value='Hold down "Ctrl" (Windows/Linux) or "Cmd" (Mac) to select multiple locations.'), S…

# %%
#@title ### Step 2: Get URLs using the URL generator based on your selection
selected_locations = location_selector.value
if not selected_locations:
  print("Please make a selection (at least 1 city) to continue")
else:
  rent_faster_urls = await url_generator(selected_locations,False,True)
# Out:
# Getting listing URLs for edmonton [RentFaster]
# Getting listing URLs for red-deer [RentFaster]
# Getting listing URLs for camrose [RentFaster]
# Getting listing URLs for spruce-grove [RentFaster]
# Getting listing URLs for st-albert [RentFaster]
# Getting listing URLs for leduc [RentFaster]
# URLs retrieved

# %%
#@title ### Step 3: Convert list of URLs into CSV - RentFaster
import ipywidgets as widgets
from IPython.display import display, clear_output

output = widgets.Output()

# Text input widget for the filename
filename_input = widgets.Text(
    value='',
    placeholder='Enter filename here',
    description='Filename:',
    disabled=False
)

# Button to trigger the save action
save_button = widgets.Button(
    description='Save as CSV',
    disabled=False,
    button_style='',
    tooltip='Save your data as a CSV file',
)

# Label for instructions
instructions = widgets.HTML(
    value="If you want to save your data as a CSV run this cell and include the name of the file you want, "
          "please <strong>ONLY use letter and numbers</strong>."
)

def save_to_csv(b):
    with output:
        clear_output(wait=True)
        filename = filename_input.value
        # Validate filename: contains only letters and numbers
        if re.match("^[a-zA-Z0-9]+$", filename):  # Ensure filename is not empty and matches the criteria
            convert_to_csv(rent_faster_urls, f"{filename}.csv")  # Call the function with the provided filename
            print(f"Data saved successfully to {filename}.csv.")
        else:
            print("Error: Filename should only contain letters and numbers and cannot be empty.")

# Set the button click event handler
save_button.on_click(save_to_csv)

# Display the widgets
display(instructions, filename_input, save_button, output)
# Out:
# HTML(value='If you want to save your data as a CSV run this cell and include the name of the file you want, pl…
# Text(value='', description='Filename:', placeholder='Enter filename here')
# Button(description='Save as CSV', style=ButtonStyle(), tooltip='Save your data as a CSV file')
# Output()

# %%
# @title ### Step 4: Range Selector - Kijiji
from ipywidgets import IntRangeSlider, VBox, Button, Output, HTML
from IPython.display import display, clear_output

range_sliders = []  # List to keep track of range sliders
selected_ranges_output = Output()  # Widget to display the selected ranges and generated numbers
generated_numbers = []
# Using HTML widget instead of Label to incorporate line breaks for new lines
description_html = HTML(
    value="This code will help you select the listing numbers you want to retrieve data from Kijiji.<br>"
          "You can select up to 3 ranges from the selector"
          "Once a range has been selected, you would need to click on <strong>'Add New Range'</strong>.<br>"
          "After selecting all your ranges you would need to click on <strong>'Generate Numbers'</strong>. If you want to delete your selection, just clear the output of <strong>THIS CELL</strong> and run it again"
)
def add_range_slider(b=None):
    """Adds a new range slider to the list and updates the display."""
    if len(range_sliders) < 3:  # Limit to 3 range sliders
        new_range_slider = IntRangeSlider(
            value=[1, 10],
            min=1,
            max=190,
            step=1,
            description='Pick a range:',
            disabled=False,
            continuous_update=False,
            orientation='horizontal',
            readout=True
        )
        range_sliders.append(new_range_slider)
        update_display()
    else:
        with selected_ranges_output:
            clear_output(wait=True)  # Clear any previous output messages
            print("Maximum of 3 ranges reached.")

def collect_ranges_and_generate_numbers(b):
    """Collects ranges from sliders, generates numbers within those ranges, and displays the result."""
    with selected_ranges_output:
        clear_output(wait=True)  # Clear the previous output
        all_ranges = [slider.value for slider in range_sliders]
        for r in all_ranges:
            generated_numbers.extend(list(range(r[0], r[1] + 1)))  # Generate numbers within the range
        print("Selected ranges:", ', '.join([f"{r[0]}-{r[1]}" for r in all_ranges]))
        print("Generated numbers:", generated_numbers)

def update_display():
    """Updates the display with all widgets."""
    clear_output(wait=True)  # Clear the previous output including sliders
    display(description_html)  # Display the instructions with HTML for line breaks
    for slider in range_sliders:
        display(slider)
    display(add_range_btn)
    display(collect_ranges_btn)
    display(selected_ranges_output)

# Button to add a new range slider
add_range_btn = Button(description='Add New Range')
add_range_btn.on_click(add_range_slider)

# Button to collect ranges and generate numbers
collect_ranges_btn = Button(description='Generate Numbers')
collect_ranges_btn.on_click(collect_ranges_and_generate_numbers)

# Initial call to add the first range slider and display everything
add_range_slider()

# Initially display the widgets
update_display()
# Out:
# HTML(value="This code will help you select the listing numbers you want to retrieve data from Kijiji.<br>You c…
# IntRangeSlider(value=(1, 10), continuous_update=False, description='Pick a range:', max=190, min=1)
# Button(description='Add New Range', style=ButtonStyle())
# Button(description='Generate Numbers', style=ButtonStyle())
# Output()

# %%
# @title ### Step 5: Get URLs using the URL generator based on your page range selection
# @markdown Now that we have the ranges selected we will scrape the URLs from each page in the listing within the Kijiji website. **Run this cell**

if not generated_numbers:
  print("Please make a selection (at least 1 city) to continue")
else:
  kijiji_urls = await url_generator(generated_numbers,True,False)
# Out:
# Getting listing URLs for AB page 31 [Kijiji]
# Getting listing URLs for AB page 32 [Kijiji]
# Getting listing URLs for AB page 33 [Kijiji]
# Getting listing URLs for AB page 34 [Kijiji]
# Attempt 1 failed, retrying...
# Attempt 2 failed, retrying...
# Getting listing URLs for AB page 35 [Kijiji]
# Getting listing URLs for AB page 36 [Kijiji]
# Getting listing URLs for AB page 37 [Kijiji]
# Getting listing URLs for AB page 38 [Kijiji]
# Getting listing URLs for AB page 39 [Kijiji]
# Getting listing URLs for AB page 40 [Kijiji]
# Getting listing URLs for AB page 41 [Kijiji]
# Getting listing URLs for AB page 42 [Kijiji]
# URLs retrieved

# %%
# @title ### Step 6: Convert list of URLs into CSV - Kijiji
import ipywidgets as widgets
from IPython.display import display, clear_output
output = widgets.Output()

# Text input widget for the filename
filename_input = widgets.Text(
    value='',
    placeholder='Enter filename here',
    description='Filename:',
    disabled=False
)

# Button to trigger the save action
save_button = widgets.Button(
    description='Save as CSV',
    disabled=False,
    button_style='',
    tooltip='Save your data as a CSV file',
)

# Label for instructions
instructions = widgets.HTML(
    value="If will need to save your URLs data as a CSV, please run this cell and include the name of the file you want, "
          "<strong>ONLY use letter and numbers</strong>."
)

def save_to_csv(b):
    with output:
        clear_output(wait=True)
        filename = filename_input.value
        # Validate filename: contains only letters and numbers
        if re.match("^[a-zA-Z0-9]+$", filename):  # Ensure filename is not empty and matches the criteria
            convert_to_csv(kijiji_urls, f"{filename}.csv")  # Call the function with the provided filename
            print(f"Data saved successfully to {filename}.csv.")
        else:
            print("Error: Filename should only contain letters and numbers and cannot be empty.")

# Set the button click event handler
save_button.on_click(save_to_csv)

# Display the widgets
display(instructions, filename_input, save_button, output)
# Out:
# HTML(value='If will need to save your URLs data as a CSV, please run this cell and include the name of the fil…
# Text(value='', description='Filename:', placeholder='Enter filename here')
# Button(description='Save as CSV', style=ButtonStyle(), tooltip='Save your data as a CSV file')
# Output()

# %% [markdown]
# **Important NOTE**
#
# Because we are dealing with 2 datasets (Kijiji and RentFaster) you will need to perform the following steps in this order:
#
# 1. Select csv with URLs from either Kijiji or RentFaster (Step 7)
# 2. Initialize variables (Step 7.1)
# 3. Perform the scraping on the selected data (Step 8)
# 4. Saved the craped data (Step 9)
#
# After you have done it once for either Kijiji or RentFaster, you will need to do perform the following steps in this order:
#
# 1. Select csv with URLs from either Kijiji or RentFaster (Step 7)
# 2. Perform the scraping on the selected data (Step 8)
# 3. Saved the craped data (Step 9)
#
# **DO NOT PERFORM** step 7.1 again as it will delete your data. Remember to download in your computer the generated CSV files to have a backup!

# %%
# @title ### Step 7: Select CSV and Website
# @markdown Please select the name of the file you have the URLs saved (from Step 6), it should be in CSV format. You also need to select the website of the URLs either Kijiji or RentFaster. After you have made your selection **you need to run this cell**

# @markdown ---
# @markdown #### Enter a file name:
file_name = "Kijiji.csv" # @param {type:"string"}
# @markdown ---
# @markdown #### Enter the website name:
website = 'kijiji' # @param ["kijiji","rentfaster"]

# %%
# @title ##### Step 7.1: Initialize/Reset global variables
# @markdown Initialize or **Reset** the following variables: `all_property_overviews_kk`, `all_unit_details_kk` for **Kijiji** and `all_property_overviews`, `all_unit_details` for **RentFaster**

# @markdown Run once to create the variables, if you run it again it will reset the variables **Use with caution as you MIGHT LOSS YOUR DATA**
all_property_overviews_kk = {}
all_unit_details_kk = {}
all_property_overviews = {}
all_unit_details = {}

# %%
# @title ### Step 8: Scrape the URLs
# @markdown Execute this cell to Scrape and Parse URLs from CSV you selected on Step 7. The results from the parsing will be saved in the following variables: `all_property_overviews_kk`, `all_unit_details_kk` for **Kijiji** and `all_property_overviews`, `all_unit_details` for **RentFaster**
try:
  await scrape_urls_from_csv(file_name,website)
  back_up_overviews.update(all_property_overviews_kk)
  back_up_overviews.update(all_property_overviews)
  back_up_details.update(all_unit_details)
  back_up_details.update(all_unit_details_kk)
except:
  print("Please run the steps above to select a file name and website")
# Out:
# URLs extracted from the CSV file: Kijiji.csv. Total URLs to scrape: 552
# Scraping started for https://www.kijiji.ca/v-apartments-condos/edmonton/u-of-a-area-apartment-for-rent-university-tower-apartments/1647498716. [1/552]
# Scraped 1 urls out of 552 total.
# Scraping started for https://www.kijiji.ca/v-commercial-office-space/calgary/office-studio-space-for-rent-in-airdrie/1689105891. [2/552]
# Scraped 2 urls out of 552 total.
# Scraping started for https://www.kijiji.ca/v-apartments-condos/edmonton/garneau-towers-apartments-bachelor-available-at-8510-111th-str/1670650415. [3/552]
# Scraped 3 urls out of 552 total.
# Attempt 1 failed, retrying...
# Scraping started for https://www.kijiji.ca/v-short-term-rental/red-deer/fully-furnished-all-inclusive-short-term-rental-in-red-deer/1688576739. [4/552]
# Scraped 4 urls out of 552 total.
# Scraping started for https://www.kijiji.ca/v-apartments-condos/medicine-hat/unique-little-bachelor-on-the-hill/1690633653. [5/552]
# Scraped 5 urls out of 552 total.
# Scraping started for https://www.kijiji.ca/v-apartments-condos/calgary/now-leasing-brand-new-1-2-and-3-bedroom-townhouses/1648119417. [6/552]
# Scraped 6 urls out of 552 total.
# Scraping started for https://www.kijiji.ca/v-room-rental-roommate/calgary/room-for-rent-acadia-se/1690595865. [7/552]
# Scraped 7 urls out of 552 total.
# Attempt 1 failed, retrying...
# Scraping started for https://www.kijiji.ca/v-apartments-condos/calgary/super-large-and-bright-1-bed-apartment-in-kensington-near-lrt/1690595687. [8/552]
# Scraped 8 urls out of 552 total.
# Scraping started for https://www.kijiji.ca/v-room-rental-roommate/calgary/female-roommate-wanted-large-furnished-room-near-uofc-sait/1690595229. [9/552]
# Scraped 9 urls out of 552 total.
# Scraping started for https://www.kijiji.ca/v-apartments-condos/calgary/brand-new-upper-3-bed-2-5-bath-2-storey-duplex-w-outdoor-parkin/1690576447. [10/552]
# Scraped 10 urls out of 552 total.
# Scraping started for https://www.kijiji.ca/v-apartments-condos/calgary/2-bedroom-suite-acadia-se/1690594337. [11/552]
# Scraped 11 urls out of 552 total.
# Scraping started for https://www.kijiji.ca/v-commercial-office-space/edmonton/southside-warehouse-office-space/1688759380. [12/552]
# Scraped 12 urls out of 552 total.
# Attempt 1 failed, retrying...
# Scraping started for https://www.kijiji.ca/v-apartments-condos/edmonton/spacious-2-bed-1-bath-3rd-floor-apartment-w-an-underground-par/1690576526. [13/552]
# Scraped 13 urls out of 552 total.
# Scraping started for https://www.kijiji.ca/v-apartments-condos/edmonton/large-2-bed-2-bath-condo-in-the-uptown-with-in-suite-laundry/1690576817. [14/552]
# Scraped 14 urls out of 552 total.
# Scraping started for https://www.kijiji.ca/v-apartments-condos/edmonton/2-bedroom-6425-101-ave-nw/1690575783. [15/552]
# Scraped 15 urls out of 552 total.
# Scraping started for https://www.kijiji.ca/v-apartments-condos/calgary/3-br-2-bath-1-2-duplex-for-rent/1690593455. [16/552]
# Scraped 16 urls out of 552 total.
# Attempt 1 failed, retrying...
# Scraping started for https://www.kijiji.ca/v-apartments-condos/edmonton/great-1-bed-1-bath-condo-in-windermere-area-with-u-g-parking/1690576695. [17/552]
# Scraped 17 urls out of 552 total.
# Attempt 1 failed, retrying...
# Scraping started for https://www.kijiji.ca/v-room-rental-roommate/lethbridge/room-for-rent-basement-suite-700-or-600-for-one-year-lease/1690593277. [18/552]
# Scraped 18 urls out of 552 total.
# Attempt 1 failed, retrying...
# Scraping started for https://www.kijiji.ca/v-apartments-condos/lethbridge/pet-friendly-two-bedroom-two-bath-with-in-suite-laundry-for-rent/1690576122. [19/552]
# Scraped 19 urls out of 552 total.
# Attempt 1 failed, retrying...
# Scraping started for https://www.kijiji.ca/v-commercial-office-space/calgary/2-66-acres-land-for-sublease-5525-57-street-se/1679339328. [20/552]
# Scraped 20 urls out of 552 total.
# Scraping started for https://www.kijiji.ca/v-apartments-condos/edmonton/great-3-bed-1-5-bath-2-storey-townhouse-w-assigned-outdoor-pa/1690576550. [21/552]
# Scraped 21 urls out of 552 total.
# Attempt 1 failed, retrying...
# Scraping started for https://www.kijiji.ca/v-apartments-condos/calgary/1-bedroom-premium-1312-12-ave-sw-renovated-suite/1690575728. [22/552]
# Scraped 22 urls out of 552 total.
# Attempt 1 failed, retrying...
# Scraping started for https://www.kijiji.ca/v-apartments-condos/calgary
urls out of 552 total.
# Attempt 1 failed, retrying...
# Scraping started for https://www.kijiji.ca/v-apartments-condos/calgary/2-bedroom-condo-rental-in-bankview-available-may-1st/1690468419. [537/552]
# Scraped 537 urls out of 552 total.
# Scraping started for https://www.kijiji.ca/v-room-rental-roommate/calgary/large-room-in-new-brighton-se-for-rent/1690467747. [538/552]
# Scraped 538 urls out of 552 total.
# Attempt 1 failed, retrying...
# Scraping started for https://www.kijiji.ca/v-short-term-rental/lloydminster-ab/rooms-for-rent/1690467735. [539/552]
# Scraped 539 urls out of 552 total.
# Scraping started for https://www.kijiji.ca/v-apartments-condos/medicine-hat/quality-home-looking-for-quality-tenants/1690467565. [540/552]
# Scraped 540 urls out of 552 total.
# Attempt 1 failed, retrying...
# Scraping started for https://www.kijiji.ca/v-room-rental-roommate/calgary/room-for-rent/1690467146. [541/552]
# Scraped 541 urls out of 552 total.
# Scraping started for https://www.kijiji.ca/v-apartments-condos/st-albert/amazing-3-bedroom-townhouse-st-albert/1682107930. [542/552]
# Scraped 542 urls out of 552 total.
# Scraping started for https://www.kijiji.ca/v-apartments-condos/st-albert/gateway-gardens:-2-bedroom-suite-st-albert/1673872480. [543/552]
# Scraped 543 urls out of 552 total.
# Attempt 1 failed, retrying...
# Attempt 2 failed, retrying...
# Scraping started for https://www.kijiji.ca/v-apartments-condos/st-albert/renovated-2-bedroom-apartment-available-st-albert/1666821859. [544/552]
# Scraped 544 urls out of 552 total.
# Scraping started for https://www.kijiji.ca/v-apartments-condos/st-albert/2-bedroom-apartment-available-in-grandin-community/1666821873. [545/552]
# Scraped 545 urls out of 552 total.
# Scraping started for https://www.kijiji.ca/v-room-rental-roommate/calgary/looking-for-a-rental-room-tuesday-and-wednesday-night-only/1690465957. [546/552]
# Scraped 546 urls out of 552 total.
# Scraping started for https://www.kijiji.ca/v-apartments-condos/calgary/2-bedrooms-2-bath-den-office/1690465594. [547/552]
# Scraped 547 urls out of 552 total.
# Scraping started for https://www.kijiji.ca/v-apartments-condos/calgary/homestead-basement-for-rent/1690465536. [548/552]
# Scraped 548 urls out of 552 total.
# Attempt 1 failed, retrying...
# Scraping started for https://www.kijiji.ca/v-apartments-condos/lethbridge/tired-of-renting-no-down-payment-we-can-help/1690465409. [549/552]
# Scraped 549 urls out of 552 total.
# Scraping started for https://www.kijiji.ca/v-apartments-condos/edmonton/fully-furnished-2-bedroom-condo-in-fox-creek/1690465155. [550/552]
# Scraped 550 urls out of 552 total.
# Attempt 1 failed, retrying...
# Scraping started for https://www.kijiji.ca/v-storage-parking/calgary/self-storage-conveniently-located-near-airdrie-balzac-calgary/1690465113. [551/552]
# Scraped 551 urls out of 552 total.
# Scraping started for https://www.kijiji.ca/v-room-rental-roommate/calgary/two-bedrooms-walkout-basement-suite-for-rent/1690464930. [552/552]
# Scraped 552 urls out of 552 total.
# Scraping Finished

# %%
# @title ### Step 9: Covert data into DataFrame and saved it as a CSV (10 pts for Kijiji - 10 pts for RentFaster)

# @markdown #### **You will need to perform this twice! Once for Kijiji and Once for RentFaster, your total files will be 4 csv.**
# @markdown ---
# @markdown Now that you have your data, you will need to save it in 2 csv files, each csv file will contain the property_id along with either the overview or the details for that listing. Once you execute this cell I strongly recommend you to download the files generated by accessing them on the left side of your google colab by clicking on the folder icon.

# @markdown ---
# @markdown #### Enter a file name for unit details data (include .csv):

filename_details = "Kijiji_details.csv" # @param {type:"string"}
# @markdown ---
# @markdown #### Enter a file name for property overview data (include .csv):
filename_overview = "Kijiji_overview.csv" # @param {type:"string"}
# @markdown #### Enter the website name of the data you want to save:
website = 'kijiji' # @param ["kijiji","rentfaster"]

try:
  if website == 'kijiji':
    convert_kijiji_to_csv(all_unit_details_kk,all_property_overviews_kk,filename_details,filename_overview)
  elif website == 'rentfaster':
    convert_rentfaster_to_csv(all_unit_details,all_property_overviews,filename_details,filename_overview)
  else:
    print("Something went wrong, please check your selections")
except:
  print("Please run all steps above before executing this cell, the data should be generated before reaching this point.")

# %% [markdown]
# ## Part 2: DataFrame, Tables creation and Yelp API setup [Data Management - Total 20 pts]
#
# At this point you should have the data from Step 9 into a CSV. In this part, you are required to convert that data into spark dataframe to perfom on them your data exploration. Remember that you will be working with the raw data from our rental housing scraper, double check ALWAYS your data to better understand what you need to do with it.

# %% [markdown]
# ### Install and set up Pyspark and its associated requirements:
#
# `pyspark` is the Python API for Apache Spark, an open-source, distributed computing system that provides an interface for programming entire clusters with implicit data parallelism and fault tolerance. When dealing with web scraped data from rental listings on RentFaster and Kijiji, `pyspark` enables efficient data processing and analysis at scale. Here's how it contributes to our project:
#
# - **Data Exploration**: `pyspark` allows for comprehensive data exploration, including summarizing datasets, querying specific information (e.g., average rental prices, most common amenities), and identifying trends within the rental market of Alberta, Canada.
#
# - **Data Transformation**: The data scraped from these websites often requires cleaning and transformation to be useful for analysis. `pyspark` provides a wide array of functions for data manipulation, such as filtering, grouping, and aggregating data. This is essential for preparing the web scraped data, which may include varying formats, missing values, or irrelevant information, into a structured and analysis-ready format.
#
# `findspark` is a helper library designed to make it easier to find and start using Apache Spark's `pyspark` within Python applications. Essentially, it simplifies the process of initializing Spark in Python scripts by locating the Spark installation (which can sometimes be a challenge due to environment variables and path configurations).
#
# - **Seamless Integration**: By using `findspark`, you can more easily integrate Apache Spark into your Python environment for web scraping projects. It ensures that `pyspark` can be imported and used in your scripts as any other Python library, without the need for cumbersome setup processes or environment configuration. This is particularly useful in educational or experimental projects where simplifying the setup process can save valuable time and effort.

# %%
 # !pip install pyspark
 # !pip install findspark
# Out:
# Collecting pyspark
#   Downloading pyspark-3.5.1.tar.gz (317.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.0/317.0 MB 4.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.5.1-py2.py3-none-any.whl size=317488491 sha256=279147abb26386837281b06a0635073b2370d5c63063ac61507211b1c9ef240a
#   Stored in directory: /root/.cache/pip/wheels/80/1d/60/2c256ed38dddce2fdd93be545214a63e02fbd8d74fb0b7f3a6
# Successfully built pyspark
# Installing collected packages: pyspark
# Successfully installed pyspark-3.5.1
# Collecting findspark
#   Downloading findspark-2.0.1-py2.py3-none-any.whl (4.4 kB)
# Installing collected packages: findspark
# Successfully installed findspark-2.0.1

# %% [markdown]
# ### Spark Libraries Explained
#
# - **`os`**: This is a standard Python library that provides a way to interact with the operating system. `os` is used to perform operations like navigating the file system, changing and retrieving directory information, managing files, and accessing environment variables.
#
# - **`findspark`**: A utility library designed to make it easier to find and connect to an Apache Spark installation from Python applications. When working with Spark, setting up environment variables and paths correctly is important to successfully starting a Spark session. `findspark` simplifies this process by automatically locating the Spark installation on your system and setting the required environment variables, eliminating the need for manual configuration.
#
# - **`findspark.init()`**: This function call is used to initialize Spark in the Python script. It must be called before importing and using `pyspark`, as it sets up the environment by locating the Spark installation and setting the necessary environment variables. This step ensures that `pyspark` can be imported without issues related to finding the Spark installation.
#
# - **`pyspark`**: The Python API for Apache Spark, `pyspark` allows Python programmers to interface with Spark's distributed data processing capabilities. By importing `pyspark`, you gain access to Spark's core functionalities, including creating RDDs (Resilient Distributed Datasets), transformations, and actions on these datasets, enabling large-scale data processing.
#
# - **`from pyspark.sql import SparkSession`**: SparkSession is the entry point to programming Spark with the Dataset and DataFrame API. A SparkSession can be used to create DataFrame objects, register DataFrame as tables, execute SQL queries, and read data from an external source. Importing SparkSession is essential for working with Spark SQL and DataFrame operations, which are powerful tools for data analysis, especially when dealing with structured data like that obtained from web scraping.

# %%
import os
import findspark
import pandas as pd
findspark.init()
# only run after findspark.init()
import pyspark
from pyspark.sql import SparkSession

# %% [markdown]
# ### Step 1: Initializing a spark cluster (5 pts)
#
# Include your code below to initialize the spark cluster and add a verification step as well. Use a meaninful name for the PySpark App Name

# %%
#Your code goes here
spark = SparkSession.builder.appName('Final_Assignment').getOrCreate()
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://83a98f530a05:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Final_Assignment</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# Verification step

# %%
df = spark.sql('''select 'spark' as hello''')
df.show()
# Out:
# +-----+
# |hello|
# +-----+
# |spark|
# +-----+

# %% [markdown]
# ### Step 2: Create dataframes for analytics [Total of 15 pts]
#
# Create the PySpark dataframe with the csv data you got from Part 1 - Step 9. Remember that you can always check your files on the left folder icon within your google colab. You can use the following link to get an idea on how to do it: https://spark.apache.org/docs/latest/sql-data-sources-csv.html
#
# **Tips:**
#
# *   You should create a independent dataframe for each csv, use meaninful names!
# *   The CSV can contain newlines, to parse it you would need to consider using the "multiLine" option for `spark.read`
# *   By default headers are not including, but you need to include them! Look for the option to accomplish this
# *   Remember to use the `<your-PySparDF>.show(truncate=False)` to see how your data is looking!
# *   Check your practice Lab6 on how yo create your headers and parameters to get data from the API

# %% [markdown]
# Step 2.1: Create PySpark dataframes **Kijiji** (5 pts)

# %%
#Your code goes here
df_Kijiji_details = spark.read.csv("Kijiji_details.csv", header = True)
df_Kijiji_details.show(5)
df_Kijiji_overview = spark.read.csv("Kijiji_overview.csv", header = True)
df_Kijiji_overview.show(5)
# Out:
# +------------+---------+---------------+---------+--------------+------------+-----------+---------+-----------------+---------------------+----------+----------------+----------------+----+-------+-----------------+----+----+---------+----------------+---------------+-------------+--------------------+---------------------+--------------+-------------+--------------------------------+-----------+-----------------------------+-----+----+-----+----------+--------+----------------+------------------+------------+---------+--------------+
# | For Rent By|Unit Type|       Bedrooms|Bathrooms|Agreement Type|Pet Friendly|Size (sqft)|Furnished|Laundry (In Unit)|Laundry (In Building)|Dishwasher|Fridge / Freezer|Air Conditioning|Yard|Balcony|Smoking Permitted| Gym|Pool|Concierge|24 Hour Security|Bicycle Parking|Storage Space|Elevator in Building|Wheelchair accessible|Braille Labels|Audio Prompts|Barrier-free Entrances and Ramps|Visual Aids|Accessible Washrooms in Suite|Hydro|Heat|Water|Cable / TV|Internet|Parking Included|Additional Options|Move-In Date|More Info|Term Agreement|
# +------------+---------+---------------+---------+--------------+------------+-----------+---------+-----------------+---------------------+----------+----------------+----------------+----+-------+-----------------+----+----+---------+----------------+---------------+-------------+--------------------+---------------------+--------------+-------------+--------------------------------+-----------+-----------------------------+-----+----+-----+----------+--------+----------------+------------------+------------+---------+--------------+
# |Professional|Apartment|              2|        1|        1 Year|     Limited|       NULL|       No|               No|                  Yes|        No|             Yes|              No|  No|    Yes|               No|  No|  No|       No|              No|             No|           No|                 Yes|                   No|            No|           No|                              No|         No|                           No|   No| Yes|  Yes|        No|      No|               0|              NULL|        NULL|     NULL|          NULL|
# |       Owner|     NULL|           NULL|     NULL|          NULL|        NULL|       NULL|       No|             NULL|                 NULL|      NULL|            NULL|            NULL|NULL|   NULL|             NULL|NULL|NULL|     NULL|            NULL|           NULL|         NULL|                NULL|                 NULL|          NULL|         NULL|                            NULL|       NULL|                         NULL| NULL|NULL| NULL|      NULL|    NULL|            NULL|              NULL|        NULL|     NULL|          NULL|
# |Professional|Apartment|Bachelor/Studio|        1|        1 Year|     Limited|       NULL|      Yes|               No|                  Yes|        No|             Yes|              No|  No|     No|               No| Yes|  No|       No|              No|             No|          Yes|                 Yes|                   No|            No|           No|                              No|         No|                           No|   No| Yes|  Yes|        No|      No|               0|              NULL|        NULL|     NULL|          NULL|
# |Professional|     NULL|        2 + Den|        2|          NULL|          No|       NULL|      Yes|             NULL|                 NULL|      NULL|            NULL|            NULL|NULL|   NULL|             NULL|NULL|NULL|     NULL|            NULL|           NULL|         NULL|                NULL|                 NULL|          NULL|         NULL|                            NULL|       NULL|                         NULL| NULL|NULL| NULL|      NULL|    NULL|            NULL|              NULL|        NULL|     NULL|          NULL|
# |       Owner|Apartment|Bachelor/Studio|        1|        1 Year|     Limited|       NULL|       No|               No|                  Yes|        No|             Yes|              No|  No|     No|               No|  No|  No|       No|              No|             No|           No|                  No|                   No|            No|           No|                              No|         No|                           No|  Yes| Yes|  Yes|        No|      No|               1|              NULL|        NULL|     NULL|          NULL|
# +------------+---------+---------------+---------+--------------+------------+-----------+---------+-----------------+---------------------+----------+----------------+----------------+----+-------+-----------------+----+----+---------+----------------+---------------+-------------+--------------------+---------------------+--------------+-------------+--------------------------------+-----------+-----------------------------+-----+----+-----+----------+--------+----------------+------------------+------------+---------+--------------+
# only showing top 5 rows
#
# +--------------------+------------------+--------------------+--------------------+--------------------+
# |         listing_url|       date_posted|             address|          price_info|         description|
# +--------------------+------------------+--------------------+--------------------+--------------------+
# |https://www.kijij...|Posted 26 days ago|{'address_1': '85...|{'amt': 184500, '...|University Tower ...|
# |https://www.kijij...|Posted 21 days ago|{'address_1': 'Ai...|{'cur': 'CAD', 't...|Amazing opportuni...|
# |https://www.kijij...| Posted 2 days ago|{'address_1': '85...|{'amt': 117000, '...|Visit our Website...|
# |https://www.kijij...|Posted 15 days ago|{'address_1': '26...|{'amt': 269500, '...|FULLY FURNISHED A...|
# |https://www.kijij...| Posted 2 days ago|{'address_1': 'Me...|{'amt': 82000, 'c...|VIEWINGS SET UP B...|
# +--------------------+------------------+--------------------+--------------------+--------------------+
# only showing top 5 rows

# %% [markdown]
# Step 2.2: Create PySpark dataframes **RentFaster** (5 pts)

# %%
# Your code goes here
df_RentFaster_details =  spark.read.csv('RentFaster_details.csv', header = True)
df_RentFaster_details.show(5)
df_RentFaster_overview =  spark.read.csv('RentFaster_overview.csv',header = True)
df_RentFaster_overview.show(5)
# Out:
# +---------------+-----------+---------+-----------+----------+----------------+-----------------+
# |        unit_id|property_id|unit_name|description|squareFeet|availabilityDate|utilitiesIncluded|
# +---------------+-----------+---------+-----------+----------+----------------+-----------------+
# |554875_Unit_411|     554875|Unit  411|     Unit A|       578|       Immediate|             Heat|
# |554875_Unit_605|     554875|Unit  605|     Unit A|       578|       Immediate|             Heat|
# |554875_Unit_606|     554875|Unit  606|     Unit A|       578|       Immediate|             Heat|
# |554875_Unit_609|     554875|Unit  609|     Unit A|       578|       Immediate|             Heat|
# |554875_Unit_610|     554875|Unit  610|     Unit A|       578|       Immediate|             Heat|
# +---------------+-----------+---------+-----------+----------+----------------+-----------------+
# only showing top 5 rows
#
# +-----------+------+-----------------+--------------------+--------------------+--------------------+--------------+----------+--------------------+--------------------+--------------------+--------------------+
# |property_id|    id|         location|                name|                 url|              slogan|    priceRange| telephone|               image|         description|             address|           amenities|
# +-----------+------+-----------------+--------------------+--------------------+--------------------+--------------+----------+--------------------+--------------------+--------------------+--------------------+
# |     554875|554875|     /ab/edmonton|          The Willow|https://www.rentf...|Get 1-month FREE ...|$1,340 - 1,555|5879903812|https://f1a3d4fea...|Discover The Will...|11009 109A Avenue...|{'Elevator': 'Tru...|
# |     540024|540024|     /ab/edmonton|The Legacy at Gri...|https://www.rentf...|The Legacy at Gri...|        $1,550|5874001246|https://f1a3d4fea...|Join us for an Op...|565 Griesbach Par...|{'Air Conditionin...|
# |     549526|549526|     /ab/edmonton|      University 114|https://www.rentf...|Modern comforts, ...|$1,282 - 2,194|5877139762|https://f1a3d4fea...|Welcome to Univer...|11329 University ...|{'Elevator': 'Tru...|
# |     561691|561691|/ab/sherwood-park|   Park Centre Place|https://www.rentf...|   Park Centre Place|$1,950 - 2,493|5875708501|https://f1a3d4fea...|1 Month Free on a...|2014 Sherwood Dri...|{'Elevator': 'Tru...|
# |     478927|478927|     /ab/edmonton|Jasper Heights Ap...|https://www.rentf...|Jasper Heights Ap...|$1,167 - 2,009|5878050277|https://f1a3d4fea...|Welcome to Jasper...|10049 103 Street,...|{'Elevator': 'Tru...|
# +-----------+------+-----------------+--------------------+--------------------+--------------------+--------------+----------+--------------------+--------------------+--------------------+--------------------+
# only showing top 5 rows

# %% [markdown]
# Step 2.3: Create Yelp Fusion API **parameters** and **headers** (5 pts)
#
# To begin, the first step is to create a Yelp Developer account, which you can accomplish by clicking [here](https://www.yelp.com/developers). After setting up your account, head to the Yelp Fusion API section on the Yelp Developer page and select 'Get Started.' This action will grant you access to API keys that are essential for fetching restaurant data, allowing you to perform queries based on addresses extracted from your rental listings. By integrating Yelp Fusion data with our scraped rental information, we can provide a comprehensive view of each listing's neighborhood amenities, enhancing the value of our dataset with actionable insights for potential renters.

# %%
# Your code goes here
import requests

api_key_ = 'HsjVUPuTRB5PlCIuRhiLiYPKh8_k8amo-x0rusX8hTelwqfHt1U75dH5smT5gA5K5NP5ZWL-_J0PL-URfKQ3KB_5dpLIgtUI-d_E13sjjpz-1ldcetFvm7cf2NUZZnYx'
address = "1039 McConachie Blvd. NW, Edmonton, AB, T5Y 3W5"

headers = {
    'Authorization': f'Bearer {api_key_}',
}

params = {
    'term': 'restaurants',
    'location': address,
    'limit': 50
}

# %% [markdown]
# ## Part 3: Explore your data [Data Analysis - Total 30 pts]
#
# Now that you have created a PySpark dataframe with data from RentFaster and Kijiji, and your code is ready to make requests to the Yelp API, you can begin exploring your data!
#
# You can leverage the Yelp Fusion API, which offers a streamlined method to enrich our web-scraped housing data from RentFaster and Kijiji with detailed information about restaurants, including their ratings, based on specific addresses. This integration enables multi-dimensional analysis, providing insights into the dining landscape surrounding rental listings.
#
# To achieve this, perform the following steps:
#
# 1.   Get the top 50 listings with the highest price from both RentFaster and Kijiji
# (a total of 100 data points, refer to point 1 on **Appendix 1**).
# 2.   Get the bottom 50 listings with the lowest price from both RentFaster and Kijiji (a total of 100 data points, refer to point 2 on **Appendix 1**).
# 3.   Collect the addresses for the top 100 and bottom 100 listings.
# 4.   Perform data cleaning on your address data to remove duplicated locations, if any, from your top and bottom 100 listings.
# 5.  Once you have clean address data, use it to make requests to the Yelp API to obtain a list (in JSON format) of all restaurants near those locations (refer to point 3 on the **Appendix 1**)
# 6.  Create 2 tables using Spark: one for all the restaurants from the top 100 listings and another for those from the bottom 100 listings.
# 7.  Perform a data exploration analysis to try to explain the relationship, if any, between the top/bottom 100 listings and the nearby restaurants. Feel free to create new tables, dataframes, or whatever else you deem necessary for your analysis.
#
# **Apendix 1: Important things to consider!!!**
#
# 1.   The price information for Kijiji listings is stored within the Kijiji overview dataset, in a column called **price_info**. This price is within a JSON string. To retrieve it, use the following approach:
#
# ```
# from pyspark.sql import SparkSession
# from pyspark.sql.functions import col
#
# # Selecting the 'amt' key from the 'price_info' column along with other specified columns
# df = <your_spark_dataframe>.select(
#     col("property_id"),
#     col("listing_url"),
#     col("date_posted"),
#     col("price_info").getItem("amt").alias("amount")
# )
#
# # Show the resulting DataFrame
# df.show()
# ```
#
# 2.   The price information for RentFaster listings is stored within the RentFaster overview dataset, in a column called priceRange. As the name suggests, some listings will have a price range; for those, select the highest price. Use the following approach to clean up the data:
#
# ```
# from pyspark.sql.functions import col, split, expr, regexp_replace, when
#
# df = <your_spark_dataframe>.withColumn(
#     "highestPrice",  # Name of your new column
#     when(
#         col("priceRange").contains(" - "),  # Check if there's a range
#         expr("array_max(transform(split(regexp_replace(priceRange, '\\$|,', ''), ' - '), x -> cast(x as int)))") # Removing $ , - and converting to int
#     ).otherwise(
#         regexp_replace(col("priceRange"), '\\$|,', '').cast("int")  # Handle single price by removing $ and commas and converting to int
#     )
# )
# # Show the resulting DataFrame with the highest price extracted
# df.show(100)
# ```
#
#
#
# 3.   Once you have cleaned your address data, store the addresses in two lists: one for the top 100 listings and another for the bottom 100 listings. You will need to make requests to the API based on these addresses, with ONE request per address. If you have 50 addresses, you need to make 50 requests. **REMEMBER THAT YOU HAVE A DAILY LIMIT**. Here is a code snippet for reference:
#
# ```
# api_key_ = 'YOUR-KEY'
# address = "1039 McConachie Blvd. NW,Edmonton,AB,T5Y 3W5"
#
# headers = {
#     'Authorization': f'Bearer {api_key}',
# }
#
# params = {
#     'term': 'restaurants',
#     'location': address,
#     'limit': 50
# }
# ```
#
# Useful links:
#
# https://docs.developer.yelp.com/reference/v3_business_search
#
# https://spark.apache.org/docs/latest/api/sql/index.html
#
# https://spark.apache.org/docs/latest/sql-ref-functions.html
#
# https://spark.apache.org/docs/latest/api/python/reference/pyspark.sql/functions.html

# %%
from pyspark.sql.functions import col, from_json
from pyspark.sql.types import StructType, StructField, StringType, IntegerType

# Selecting the 'amt' key from the 'price_info' column along with other specified columns
#This is to defined the schema of the new column 'price_info_struct'
price_info_schema = StructType([
StructField("amt", IntegerType()),
StructField("cur", StringType()),
StructField("t", StringType())
])

#This is to defined the schema of the new column 'address_struct'
address_schema = StructType([
StructField("address_1", StringType()),
StructField("address_2", StringType())
])

#We add the new column along the schema we defined above, kijiji_overview_spark_df is the data frame you created from the CSV file!
df = df_Kijiji_overview.withColumn("price_info_struct", from_json(col("price_info"), price_info_schema))
df = df.withColumn("address_struct", from_json(col("address"), address_schema))

#We stract the data from the 'address_struct' and 'price_info_struct' to create 3 new columns 'amount', 'address_1' and 'address_2'
df_Kijiji_struct = df.withColumn("amount", col("price_info_struct").amt) \
.withColumn("address_1", col("address_struct").address_1) \
.withColumn("address_2", col("address_struct").address_2)

df_Kijiji_struct.show(5)
# Out:
# +--------------------+------------------+--------------------+--------------------+--------------------+--------------------+--------------------+------+--------------------+--------------------+
# |         listing_url|       date_posted|             address|          price_info|         description|   price_info_struct|      address_struct|amount|           address_1|           address_2|
# +--------------------+------------------+--------------------+--------------------+--------------------+--------------------+--------------------+------+--------------------+--------------------+
# |https://www.kijij...|Posted 26 days ago|{'address_1': '85...|{'amt': 184500, '...|University Tower ...|{184500, CAD, FIXED}|{8515 112 Street ...|184500|8515 112 Street N...|8515 112 Street N...|
# |https://www.kijij...|Posted 21 days ago|{'address_1': 'Ai...|{'cur': 'CAD', 't...|Amazing opportuni...|{NULL, CAD, CONTACT}|{Airdrie, AB T4B ...|  NULL| Airdrie, AB T4B 2W9|                NULL|
# |https://www.kijij...| Posted 2 days ago|{'address_1': '85...|{'amt': 117000, '...|Visit our Website...|{117000, CAD, FIXED}|{8510 111th Stree...|117000|8510 111th Street...|8510 111th Street...|
# |https://www.kijij...|Posted 15 days ago|{'address_1': '26...|{'amt': 269500, '...|FULLY FURNISHED A...|{269500, CAD, FIXED}|{260 Duston Stree...|269500|260 Duston Street...|                NULL|
# |https://www.kijij...| Posted 2 days ago|{'address_1': 'Me...|{'amt': 82000, 'c...|VIEWINGS SET UP B...| {82000, CAD, FIXED}|{Medicine Hat, AB...| 82000|Medicine Hat, AB ...|Medicine Hat, AB ...|
# +--------------------+------------------+--------------------+--------------------+--------------------+--------------------+--------------------+------+--------------------+--------------------+
# only showing top 5 rows

# %%
# top 50 data points from bottom
from pyspark.sql import SparkSession
from pyspark.sql.functions import col

# Selecting the 'amt' key from the 'price_info' column along with other specified columns
df_Kijiji = df_Kijiji_struct.select(
    col("listing_url"),
    col("address_1"),
    col("price_info_struct").getItem("amt").alias("amount")
)
df_Kijiji.show(3)
# Out:
# +--------------------+--------------------+------+
# |         listing_url|           address_1|amount|
# +--------------------+--------------------+------+
# |https://www.kijij...|8515 112 Street N...|184500|
# |https://www.kijij...| Airdrie, AB T4B 2W9|  NULL|
# |https://www.kijij...|8510 111th Street...|117000|
# +--------------------+--------------------+------+
# only showing top 3 rows

# %%
from pyspark.sql.functions import col
df_Kijiji = df_Kijiji.filter(col("amount").isNotNull())

# %%
df_Kijiji.createOrReplaceTempView("df_Kijiji")

# %%
query = "SELECT * FROM df_Kijiji order by amount DESC limit 50"
spark.sql(query).show(3)
# Out:
# +--------------------+--------------------+-------+
# |         listing_url|           address_1| amount|
# +--------------------+--------------------+-------+
# |https://www.kijij...|57 Street Southea...|1260000|
# |https://www.kijij...|Sturgeon County, ...| 650000|
# |https://www.kijij...| Calgary, AB T3L 3B3| 549500|
# +--------------------+--------------------+-------+
# only showing top 3 rows

# %%
df_Kijiji_highest = spark.sql(query)

# %%
query = "SELECT * FROM df_Kijiji order by amount limit 50"
spark.sql(query).show(3)
# Out:
# +--------------------+--------------------+------+
# |         listing_url|           address_1|amount|
# +--------------------+--------------------+------+
# |https://www.kijij...|4907 1st Avenue, ...|   500|
# |https://www.kijij...|4604 97 St, Edmon...|  1300|
# |https://www.kijij...|3 St SE, Calgary,...|  1600|
# +--------------------+--------------------+------+
# only showing top 3 rows

# %%
query = "SELECT * FROM df_Kijiji order by amount limit 50"
spark.sql(query).show(3)
# Out:
# +--------------------+--------------------+------+
# |         listing_url|           address_1|amount|
# +--------------------+--------------------+------+
# |https://www.kijij...|4907 1st Avenue, ...|   500|
# |https://www.kijij...|4604 97 St, Edmon...|  1300|
# |https://www.kijij...|3 St SE, Calgary,...|  1600|
# +--------------------+--------------------+------+
# only showing top 3 rows

# %%
df_Kijiji_lowest = spark.sql(query)

# %%
from pyspark.sql.functions import col, split, expr, regexp_replace, when

df_RentFaster_highest = df_RentFaster_overview.withColumn(
    "highestPrice",  # Name of your new column
    when(
        col("priceRange").contains(" - "),  # Check if there's a range
        expr("array_max(transform(split(regexp_replace(priceRange, '\\$|,', ''), ' - '), x -> cast(x as int)))") # Removing $ , - and converting to int
    ).otherwise(
        regexp_replace(col("priceRange"), '\\$|,', '').cast("int")  # Handle single price by removing $ and commas and converting to int
    )
).orderBy("highestPrice", ascending=False).dropna().limit(50)

# Show the resulting DataFrame with the highest price extracted
df_RentFaster_highest.show(5)
# Out:
# +-----------+------+-----------------+--------------------+--------------------+--------------------+----------+----------+--------------------+--------------------+--------------------+--------------------+------------+
# |property_id|    id|         location|                name|                 url|              slogan|priceRange| telephone|               image|         description|             address|           amenities|highestPrice|
# +-----------+------+-----------------+--------------------+--------------------+--------------------+----------+----------+--------------------+--------------------+--------------------+--------------------+------------+
# |     463222|463222|     /ab/edmonton|       Rio Park Home|https://www.rentf...|Executive 2-story...|    $5,900|5874042378|https://f1a3d4fea...|Executive 2storey...|15515 RIO Park Rd...|{'Bike Paths': 'T...|        5900|
# |     521403|521403|     /ab/red-deer|  124 Anderson Close|https://www.rentf...|Cozy Renovated/Up...|    $5,870|4033477791|/img/virtual-tour...|5 Bedroom 25 Bath...|124 Anderson Clos...|{'Dishwasher': 'T...|        5870|
# |     532993|532993|     /ab/edmonton|601 - 14105 West ...|https://www.rentf...|601 - 14105 West ...|    $5,100|7809205561|https://f1a3d4fea...|Introducing Edmon...|601 - 14105 West ...|{'Dishwasher': 'T...|        5100|
# |     564055|564055|/ab/sherwood-park|13 52249 Range Ro...|https://www.rentf...|Country living in...|    $5,000|7802380008|https://f1a3d4fea...|Country living in...|13 52249 Range Ro...|{'Dishwasher': 'T...|        5000|
# |     531465|531465|     /ab/edmonton|Legends Private R...|https://www.rentf...|Legends Private R...|    $4,900|7807842518|https://f1a3d4fea...|Welcome to luxury...|10360 102 St NW, ...|{'Air Conditionin...|        4900|
# +-----------+------+-----------------+--------------------+--------------------+--------------------+----------+----------+--------------------+--------------------+--------------------+--------------------+------------+
# only showing top 5 rows

# %%
from pyspark.sql.functions import col, split, expr, regexp_replace, when

df_RentFaster_lowest = df_RentFaster_overview.withColumn(
    "lowestPrice",  # Name of your new column
    when(
        col("priceRange").contains(" - "),  # Check if there's a range
        expr("array_max(transform(split(regexp_replace(priceRange, '\\$|,', ''), ' - '), x -> cast(x as int)))") # Removing $ , - and converting to int
    ).otherwise(
        regexp_replace(col("priceRange"), '\\$|,', '').cast("int")  # Handle single price by removing $ and commas and converting to int
    )
).orderBy("lowestPrice", ascending=True).dropna().limit(50)

# Show the resulting DataFrame with the highest price extracted
df_RentFaster_lowest.show(5)
# Out:
# +-----------+------+-------------+--------------------+--------------------+--------------------+----------+----------+--------------------+--------------------+--------------------+--------------------+-----------+
# |property_id|    id|     location|                name|                 url|              slogan|priceRange| telephone|               image|         description|             address|           amenities|lowestPrice|
# +-----------+------+-------------+--------------------+--------------------+--------------------+----------+----------+--------------------+--------------------+--------------------+--------------------+-----------+
# |     411812|411812|/ab/st-albert|     20 Circle Drive|https://www.rentf...|*Garage Storage A...|      $150|7804431161|https://f1a3d4fea...|In need of extra ...|20 Circle Drive, ...|                  {}|        150|
# |     510049|510049| /ab/edmonton|           Allendale|https://www.rentf...|JUST RENOVATED! O...|      $475|7804370450|https://f1a3d4fea...|JUST RENOVATED In...|           Undefined|{'Guest Parking':...|        475|
# |     563170|563170| /ab/edmonton|            Kilkenny|https://www.rentf...|2 Large room avai...|      $500|5879203662|https://f1a3d4fea...|Large bright furn...|           Undefined|{'Laundry - Share...|        500|
# |     562328|562328| /ab/edmonton|9514 102A Avenue ...|https://www.rentf...|Single room, c/w ...|      $500|7802923975|https://f1a3d4fea...|Single furnished ...|9514 102A Avenue ...|{'Laundry - Coin/...|        500|
# |     555500|555500| /ab/edmonton|15610 141 Street ...|https://www.rentf...|Room for rent nor...|      $550|7807223479|https://f1a3d4fea...|Hello we are look...|15610 141 Street ...|{'Laundry - Share...|        550|
# +-----------+------+-------------+--------------------+--------------------+--------------------+----------+----------+--------------------+--------------------+--------------------+--------------------+-----------+
# only showing top 5 rows

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col

# Assuming df_Kijiji_highest and df_RentFaster_highest are already defined DataFrames
df_Kijiji_selected_top50 = df_Kijiji_highest.select("listing_url", "address_1", "amount")
df_RentFaster_selected_top50 = df_RentFaster_highest.select("url", "address", "highestPrice")
df_combined_top100 = df_Kijiji_selected_top50.union(df_RentFaster_selected_top50).orderBy("amount")
df_Kijiji_selected_top50.show(5)
df_RentFaster_selected_top50.show(5)
df_combined_top100.show(100)
# Out:
# +--------------------+--------------------+-------+
# |         listing_url|           address_1| amount|
# +--------------------+--------------------+-------+
# |https://www.kijij...|57 Street Southea...|1260000|
# |https://www.kijij...|Sturgeon County, ...| 650000|
# |https://www.kijij...| Calgary, AB T3L 3B3| 549500|
# |https://www.kijij...|Chestermere Blvd,...| 380000|
# |https://www.kijij...| Calgary, AB T2S 3B8| 369900|
# +--------------------+--------------------+-------+
# only showing top 5 rows
#
# +--------------------+--------------------+------------+
# |                 url|             address|highestPrice|
# +--------------------+--------------------+------------+
# |https://www.rentf...|15515 RIO Park Rd...|        5900|
# |https://www.rentf...|124 Anderson Clos...|        5870|
# |https://www.rentf...|601 - 14105 West ...|        5100|
# |https://www.rentf...|13 52249 Range Ro...|        5000|
# |https://www.rentf...|10360 102 St NW, ...|        4900|
# +--------------------+--------------------+------------+
# only showing top 5 rows
#
# +--------------------+--------------------+-------+
# |         listing_url|           address_1| amount|
# +--------------------+--------------------+-------+
# |https://www.rentf...|1806 - 9835 113 S...|   2650|
# |https://www.rentf...|25 Meadowbrook Wa...|   2650|
# |https://www.rentf...|329 - 260 Duston ...|   2695|
# |https://www.rentf...|219 - 260 Duston ...|   2695|
# |https://www.rentf...|4608 Westcliff Po...|   2700|
# |https://www.rentf...|11020 Jasper Ave....|   2725|
# |https://www.rentf...|           Undefined|   2750|
# |https://www.rentf...|1505 - 10226 104 ...|   2750|
# |https://www.rentf...|8003 2 Avenue Sou...|   2750|
# |https://www.rentf...|6327 109A Street ...|   2750|
# |https://www.rentf...|3620 166 Avenue N...|   2800|
# |https://www.rentf...|11329 35 Avenue N...|   2800|
# |https://www.rentf...|2318 Cassidy Way ...|   2800|
# |https://www.rentf...|11710 87 Ave, Edm...|   2800|
# |https://www.rentf...|57 Carlyle Cresce...|   2800|
# |https://www.rentf...|11041 86 Ave, Edm...|   2850|
# |https://www.rentf...|106 - 10006 83 Av...|   2895|
# |https://www.rentf...|130 Element Dr NW...|   2895|
# |https://www.rentf...|22135 96 Avenue N...|   2900|
# |https://www.rentf...|168 Windermere Dr...|   2900|
# |https://www.rentf...|10360 102 Street ...|   2900|
# |https://www.rentf...|15443 133 Street ...|   2900|
# |https://www.rentf...|9733 111 St NW, E...|   2919|
# |https://www.rentf...|15548 49 Street N...|   2950|
# |https://www.rentf...|8 Chambery Cresce...|   2950|
# |https://www.rentf...|10301 109 Street ...|   2960|
# |https://www.rentf...|10058 102 St NW, ...|   2995|
# |https://www.rentf...|           Undefined|   3000|
# |https://www.rentf...|3505 - 10320- 102...|   3000|
# |https://www.rentf...|10620 99 Avenue, ...|   3026|
# |https://www.rentf...|10310 102 St NW, ...|   3100|
# |https://www.rentf...|101 St 10423, Edm...|   3110|
# |https://www.rentf...|3410 - 10360 102 ...|   3200|
# |https://www.rentf...|10855 Saskatchewa...|   3200|
# |https://www.rentf...|10232 115 Street ...|   3200|
# |https://www.rentf...|207 - 11503 100 A...|   3225|
# |https://www.rentf...|10110 120 STREET ...|   3256|
# |https://www.rentf...|10301 109 St., Ed...|   3495|
# |https://www.rentf...|           Undefined|   3500|
# |https://www.rentf...|15718 111 Street ...|   3500|
# |https://www.rentf...|2510 - 10360 102 ...|   3900|
# |https://www.rentf...|11130 86 Avenue N...|   3995|
# |https://www.rentf...|9433 67A Avenue N...|   4400|
# |https://www.rentf...|Riverside Crescen...|   4500|
# |https://www.rentf...|25 Kingsbury Cres...|   4650|
# |https://www.rentf...|10360 102 St NW, ...|   4900|
# |https://www.rentf...|13 52249 Range Ro...|   5000|
+

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col

# Assuming df_Kijiji_highest and df_RentFaster_highest are already defined DataFrames
df_Kijiji_selected_low50 = df_Kijiji_lowest.select("listing_url", "address_1", "amount")
df_RentFaster_selected_low50 = df_RentFaster_lowest.select("url", "address", "lowestPrice")
df_combined_low100 = df_Kijiji_selected_low50.union(df_RentFaster_selected_low50).orderBy("amount")
df_Kijiji_selected_low50.show(5)
df_RentFaster_selected_low50.show(5)
df_combined_low100.show(5)
# Out:
# +--------------------+--------------------+------+
# |         listing_url|           address_1|amount|
# +--------------------+--------------------+------+
# |https://www.kijij...|4907 1st Avenue, ...|   500|
# |https://www.kijij...|4604 97 St, Edmon...|  1300|
# |https://www.kijij...|3 St SE, Calgary,...|  1600|
# |https://www.kijij...|     Calgary, AB T2E|  1600|
# |https://www.kijij...|  Calmar, AB, Canada|  3500|
# +--------------------+--------------------+------+
# only showing top 5 rows
#
# +--------------------+--------------------+-----------+
# |                 url|             address|lowestPrice|
# +--------------------+--------------------+-----------+
# |https://www.rentf...|20 Circle Drive, ...|        150|
# |https://www.rentf...|           Undefined|        475|
# |https://www.rentf...|           Undefined|        500|
# |https://www.rentf...|9514 102A Avenue ...|        500|
# |https://www.rentf...|15610 141 Street ...|        550|
# +--------------------+--------------------+-----------+
# only showing top 5 rows
#
# +--------------------+--------------------+------+
# |         listing_url|           address_1|amount|
# +--------------------+--------------------+------+
# |https://www.rentf...|20 Circle Drive, ...|   150|
# |https://www.rentf...|           Undefined|   475|
# |https://www.kijij...|4907 1st Avenue, ...|   500|
# |https://www.rentf...|           Undefined|   500|
# |https://www.rentf...|9514 102A Avenue ...|   500|
# +--------------------+--------------------+------+
# only showing top 5 rows

# %%
df_combined_top100_cleaned = df_combined_top100.select("listing_url", "address_1", "amount").dropDuplicates()
df_combined_low100_cleaned = df_combined_low100.select("listing_url", "address_1", "amount").dropDuplicates()

# %%
df_combined_top100_cleaned.registerTempTable("df_combined_top100_table")
df_combined_low100_cleaned.registerTempTable("df_combined_low100_table")

# %%
address_top100 = spark.sql("SELECT address_1 FROM df_combined_top100_table")
address_list_top100 = address_top100.rdd.map(lambda row: row[0]).collect()

address_low100 = spark.sql("SELECT address_1 FROM df_combined_low100_table")
address_list_low100 = address_low100.rdd.map(lambda row: row[0]).collect()

# %%
import requests

api_key = 'HsjVUPuTRB5PlCIuRhiLiYPKh8_k8amo-x0rusX8hTelwqfHt1U75dH5smT5gA5K5NP5ZWL-_J0PL-URfKQ3KB_5dpLIgtUI-d_E13sjjpz-1ldcetFvm7cf2NUZZnYx'

headers_top = {
    'Authorization': f'Bearer {api_key}',
}
for address_top in address_list_low100:
  params_top = {
    'term': 'restaurants',
    'location': address_top,
    'radius': 4000
  }

# %%
response = requests.get("https://api.yelp.com/v3/businesses/search", headers=headers_top, params=params_top)
Yelp_data_top = response.json()
Yelp_data_top
# Out:
# {'businesses': [{'id': 'sVwbevTHJK6SmZxBIHzm5g',
#    'alias': 'campiō-brewing-co-edmonton',
#    'name': 'Campiō Brewing Co',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RhK0KAWH1gGVCgpcm3eP_w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/campi%C5%8D-brewing-co-edmonton?adjust_creative=DUaZ2NSU0hA5L7xLRZNoXA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DUaZ2NSU0hA5L7xLRZNoXA',
#    'review_count': 48,
#    'categories': [{'alias': 'tradamerican', 'title': 'American'},
#     {'alias': 'breweries', 'title': 'Breweries'}],
#    'rating': 4.3,
#    'coordinates': {'latitude': 53.54431, 'longitude': -113.5007},
#    'transactions': [],
#    'location': {'address1': '10257 105 Street NW',
#     'address2': '',
#     'address3': None,
#     'city': 'Edmonton',
#     'zip_code': 'T5J 1E3',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['10257 105 Street NW',
#      'Edmonton, AB T5J 1E3',
#      'Canada']},
#    'phone': '+15876351952',
#    'display_phone': '+1 587-635-1952',
#    'distance': 1425.9308491167137,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'HQYPKYnuVphFs1tDpuVmZw',
#    'alias': 'hus-noodle-nook-edmonton',
#    'name': "Hu's Noodle Nook",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RddBpDPoWrJ_wF8E63gtCQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hus-noodle-nook-edmonton?adjust_creative=DUaZ2NSU0hA5L7xLRZNoXA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DUaZ2NSU0hA5L7xLRZNoXA',
#    'review_count': 2,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 53.546913, 'longitude': -113.515102},
#    'transactions': [],
#    'location': {'address1': '11238 104 Avenue NW',
#     'address2': '',
#     'address3': None,
#     'city': 'Edmonton',
#     'zip_code': 'T5K 2X4',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['11238 104 Avenue NW',
#      'Edmonton, AB T5K 2X4',
#      'Canada']},
#    'phone': '+17802502600',
#    'display_phone': '+1 780-250-2600',
#    'distance': 1359.3651460834205,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'http://husnoodlenook.ca/Ramen.html',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': '3koeM2Blt-4rEmVIJAZf8Q',
#    'alias': 'woodwork-edmonton',
#    'name': 'Woodwork',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/XHIpmhR3bR6RuSfIXoqnMQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/woodwork-edmonton?adjust_creative=DUaZ2NSU0hA5L7xLRZNoXA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DUaZ2NSU0hA5L7xLRZNoXA',
#    'review_count': 175,
#    'categories': [{'alias': 'newcanadian', 'title': 'Canadian (New)'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.2,
#    'coordinates': {'latitude': 53.5419431693898,
#     'longitude': -113.490731079867},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '10132-100 Street',
#     'address2': None,
#     'address3': '',
#     'city': 'Edmonton',
#     'zip_code': 'T5J 0N8',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['10132-100 Street', 'Edmonton, AB T5J 0N8', 'Canada']},
#    'phone': '+17807574100',
#    'display_phone': '+1 780-757-4100',
#    'distance': 1877.9805173078248,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'http://woodworkyeg.com/menus/',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': '00uLQHBVirvmfv4pGlIBGA',
#    'alias': 'baobao-edmonton',
#    'name': 'BaoBao',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/wuzlhZq75S-Yb9aartvWUQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/baobao-edmonton?adjust_creative=DUaZ2NSU0hA5L7xLRZNoXA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DUaZ2NSU0hA5L7xLRZNoXA',
#    'review_count': 44,
#    'categories': [{'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'dumplings', 'title': 'Dumplings'}],
#    'rating': 4.3,
#    'coordinates': {'latitude': 53.54136, 'longitude': -113.50214},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '10544 Jasper Avenue',
#     'address2': '',
#     'address3': '',
#     'city': 'Edmonton',
#     'zip_code': 'T5J 1Z7',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['10544 Jasper Avenue',
#      'Edmonton, AB T5J 1Z7',
#      'Canada']},
#    'phone': '+15875235747',
#    'display_phone': '+1 587-523-5747',
#    'distance': 1743.927973615149,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'https://baobaoedmonton.com/menu/',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'ivpULDSBS4mP3mJqmziKQw',
#    'alias': 'cafe-amore-bistro-edmonton-3',
#    'name': 'Cafe Amore Bistro',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/z6lhB60i8EQsVjUU3AWnsg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-amore-bistro-edmonton-3?adjust_creative=DUaZ2NSU0hA5L7xLRZNoXA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DUaZ2NSU0hA5L7xLRZNoXA',
#    'review_count': 150,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.3,
#    'coordinates': {'latitude': 53.5496883, 'longitude': -113.5068932},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '10807 106 Avenue NW',
#     'address2': '',
#     'address3': '',
#     'city': 'Edmonton',
#     'zip_code': 'T5H 4A7',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['10807 106 Avenue NW',
#      'Edmonton, AB T5H 4A7',
#      'Canada']},
#    'phone': '+17804777896',
#    'display_phone': '+1 780-477-7896',
#    'distance': 845.2383177047267,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'JSy4YZ0HkvMOohyGMIrPNQ',
#    'alias': 'calle-mexico-edmonton',
#    'name': 'Calle Mexico',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/uV6qg2pVMPg-llpbiphrkQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/calle-mexico-edmonton?adjust_creative=DUaZ2NSU0hA5L7xLRZNoXA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DUaZ2NSU0hA5L7xLRZNoXA',
#    'review_count': 118,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'foodtrucks', 'title': 'Food Trucks'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 53.55121, 'longitude': -113.5134},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '11127 107th Avenue',
#     'address2': '',
#     'address3': '',
#     'city': 'Edmonton',
#     'zip_code': 'T5H 0X9',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['11127 107th Avenue',
#      'Edmonton, AB T5H 0X9',
#      'Canada']},
#    'phone': '+17807050901',
#    'display_phone': '+1 780-705-0901',
#    'distance': 918.1617040498594,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'http://www.callemexicofoodtruck.com/menu',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'lPPYZr1_jx0XeW-xR9WJtw',
#    'alias': 'dosc-edmonton',
#    'name': 'DOSC',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/d08xhGLEgbd_5Vw13ZhBXA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dosc-edmonton?adjust_creative=DUaZ2NSU0hA5L7xLRZNoXA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DUaZ2NSU0hA5L7xLRZNoXA',
#    'review_count': 119,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 53.5428720872819,
#     'longitude': -113.499512283622},
#    'transactions': [],
#    'location': {'address1': '10190 - 104 Street NW',
#     'address2': 'Main Floor',
#     'address3': None,
#     'city': 'Edmonton',
#     'zip_code': 'T5J 1A7',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['10190 - 104 Street NW',
#      'Main Floor',
#      'Edmonton, AB T5J 1A7',
#      'Canada']},
#    'phone': '+17805400606',
#    'display_phone': '+1 780-540-0606',
#    'distance': 1595.744946892782,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'http://www.dosc.ca/menu',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'gtXAx_G5j6K1TmuJ2v5Rbg',
#    'alias': 'rge-rd-edmonton',
#    'name': 'RGE RD',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Br_RNNJuBFsjMiDqaWt3LA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rge-rd-edmonton?adjust_creative=DUaZ2NSU0hA5L7xLRZNoXA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DUaZ2NSU0hA5L7xLRZNoXA',
#    'review_count': 180,
#    'categories': [{'alias': 'newcanadian', 'title': 'Canadian (New)'}],
#    'rating': 4.4,
#    'coordinates': {'latitude': 53.5507814, 'longitude': -113.5338044},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '10643 - 123 Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Edmonton',
#     'zip_code': 'T5M 1Z1',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['10643 - 123 Street',
#      'Edmonton, AB T5M 1Z1',
#      'Canada']},
#    'phone': '+17804474577',
#    'display_phone': '+1 780-447-4577',
#    'distance': 2116.6893460461592,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'Z2gGsSqf9KknTvMGp1yByw',
#    'alias': 'moxies-edmonton-2',
#    'name': 'Moxies',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/vEC6aSnBDNxPhXr3Gkgp1g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/moxies-edmonton-2?adjust_creative=DUaZ2NSU0hA5L7xLRZNoXA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DUaZ2NSU0hA5L7xLRZNoXA',
#    'review_count': 49,
#    'categories': [{'alias': 'newcanadian', 'title': 'Canadian (New)'},
#     {'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'lounges', 'title': 'Lounges'}],
#    'rating': 3.2,
#    'coordinates': {'latitude': 53.559431, 'longitude': -113.5046145},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '10628 Kingsway Avenue',
#     'address2': '',
#     'address3': '',
#     'city': 'Edmonton',
#     'zip_code': 'T5G 0W8',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['10628 Kingsway Avenue',
#      'Edmonton, AB T5G 0W8',
#      'Canada']},
#    'phone': '+17809440232',
#    'display_phone': '+1 780-944-0232',
#    'distance': 252.7920213566803,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': '',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'qoD6-nDDfEuNPRJipJxpOA',
#    'alias': 'oeb-breakfast-edmonton-4',
#    'name': 'OEB Breakfast',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/OAwa2JhwInGmkEBXRMzUfw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/oeb-breakfast-edmonton-4?adjust_creative=DUaZ2NSU0hA5L7xLRZNoXA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DUaZ2NSU0hA5L7xLRZNoXA',
#    'review_count': 250,
#    'categories': [{'alias': 'breakfast_brunch',
#      'title': 'Breakfast & Brunch'}],
#    'rating': 4.4,
#    'coordinates': {'latitude': 53.542609, 'longitude': -113.492594},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '10174 100A Street',
#     'address2': None,
#     'address3': '',
#     'city': 'Edmonton',
#     'zip_code': 'T5J 0H3',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['10174 100A Street',
#      'Edmonton, AB T5J 0H3',
#      'Canada']},
#    'phone': '+15875200936',
#    'display_phone': '+1 587-520-0936',
#    'distance': 1757.6266106823377,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'http://eatoeb.com/menu/',
#     'open24_hours': None,
#     'waitlist_reservation': True}},
#   {'id': '-jqZKflff1oagRdl2eTg5Q',
#    'alias': 'ashford-house-pub-and-kitchen-edmonton',
#    'name': 'Ashford House Pub & Kitchen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/mAUoOKzvEQgcAJGeAcfZwQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ashford-house-pub-and-kitchen-edmonton?adjust_creative=DUaZ2NSU0hA5L7xLRZNoXA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DUaZ2NSU0hA5L7xLRZNoXA',
#    'review_count': 4,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'irish_pubs', 'title': 'Irish Pub'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 53.5514782, 'longitude': -113.5298359},
#    'transactions': [],
#    'location': {'address1': '12026 107 Avenue NW',
#     'address2': '',
#     'address3': None,
#     'city': 'Edmonton',
#     'zip_code': 'T5H 0Z2',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['12026 107 Avenue NW',
#      'Edmonton, AB T5H 0Z2',
#      'Canada']},
#    'phone': '+15874003204',
#    'display_phone': '+1 587-400-3204',
#    'distance': 1843.848074015876,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'fdez0D4ovth2k1IvR0ZbpQ',
#    'alias': 'sabor-edmonton',
#    'name': 'Sabor',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/OTkw-L-93zoKsAqn8GNT_w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sabor-edmonton?adjust_creative=DUaZ2NSU0hA5L7xLRZNoXA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DUaZ2NSU0hA5L7xLRZNoXA',
#    'review_count': 185,
#    'categories': [{'alias': 'portuguese', 'title': 'Portuguese'},
#     {'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 4.3,
#    'coordinates': {'latitude': 53.543381087231,
#     'longitude': -113.497605148344},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '10220 103 Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Edmonton',
#     'zip_code': 'T5J 4A1',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['10220 103 Street', 'Edmonton, AB T5J 4A1', 'Canada']},
#    'phone': '+17807571114',
#    'display_phone': '+1 780-757-1114',
#    'distance': 1566.6162640061495,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': '2f9zoxMg6hmonYNR6zxBDw',
#    'alias': 'dogpatch-edmonton',
#    'name': 'Dogpatch',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/1LxwG3RbreNbLMMtHHgyZg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dogpatch-edmonton?adjust_creative=DUaZ2NSU0hA5L7xLRZNoXA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DUaZ2NSU0hA5L7xLRZNoXA',
#    'review_count': 26,
#    'categories': [{'alias': 'bistros', 'title': 'Bistros'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 53.54468327770364,
#     'longitude': -113.47114641219376},
#    'transactions': [],
#    'location': {'address1': '10158 90 Street NW',
#     'address2': '',
#     'address3': None,
#     'city': 'Edmonton',
#     'zip_code': 'T5H 1R7',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['10158 90 Street NW',
#      'Edmonton, AB T5H 1R7',
#      'Canada']},
#    'phone': '+17807618700',
#    'display_phone': '+1 780-761-8700',
#    'distance': 2541.655177286034,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'http://dogpatchyeg.ca/#menu',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'l7DhJNwumsbDK9cuusE9sQ',
#    'alias': 'bundok-edmonton-3',
#    'name': 'Bundok',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/39692OqhRjCeWhdCFwfssA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bundok-edmonton-3?adjust_creative=DUaZ2NSU0hA5L7xLRZNoXA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DUaZ2NSU0hA5L7xLRZNoXA',
#    'review_count': 55,
#    'categories': [{'alias': 'newcanadian', 'title': 'Canadian (New)'}],
#    'rating': 4.4,
#    'coordinates': {'latitude': 53.54366, 'longitude': -113.4994049},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '10228 104 Street NW',
#     'address2': '',
#     'address3': None,
#     'city': 'Edmonton',
#     'zip_code': 'T5J 1B8',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['10228 104 Street NW',
#      'Edmonton, AB T5J 1B8',
#      'Canada']},
#    'phone': '+17804200192',
#    'display_phone': '+1 780-420-0192',
#    'distance': 1505.373097767792,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'mCzVir1MfsI6_V3jPkCn6Q',
#    'alias': 'pur-and-simple-edmonton',
#    'name': 'Pur & Simple',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/QJlzKpJsLFH20qNDwWSx7g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pur-and-simple-edmonton?adjust_creative=DUaZ2NSU0hA5L7xLRZNoXA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DUaZ2NSU0hA5L7xLRZNoXA',
#    'review_count': 5,
#    'categories': [{'alias': 'breakfast_brunch',
#      'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 53.561900054875416,
#     'longitude': -113.50647174289574},
#    'transactions': [],
#    'location': {'address1': '1 Kingsway Garden Mall NW',
#     'address2': '',
#     'address3': None,
#     'city': 'Edmonton',
#     'zip_code': 'T5G 3A6',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['1 Kingsway Garden Mall NW',
#      'Edmonton, AB T5G 3A6',
#      'Canada']},
#    'phone': '+17802500037',
#    'display_phone': '+1 780-250-0037',
#    'distance': 576.0233341151322,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'https://pursimple.com/wp-content/uploads/2021/06/NEWMenu-DigitalCopy-8.5x11-1.pdf',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': '36F6K3PGGV2ICZBNDoh0wg',
#    'alias': 'baijiu-edmonton',
#    'name': 'Baijiu',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/GlJ1I-FBRASUV26yqDbQqg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/baijiu-edmonton?adjust_creative=DUaZ2NSU0hA5L7xLRZNoXA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DUaZ2NSU0hA5L7xLRZNoXA',
#    'review_count': 57,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.4,
#    'coordinates': {'latitude': 53.5459076, 'longitude': -113.4990951},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '103-10359 104 Street NW',
#     'address2': None,
#     'address3': '',
#     'city': 'Edmonton',
#     'zip_code': 'T5J 1B9',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['103-10359 104 Street NW',
#      'Edmonton, AB T5J 1B9',
#      'Canada']},
#    'phone': '+17804217060',
#    'display_phone': '+1 780-421-7060',
#    'distance': 1276.3258686052727,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'caZG8hhW4ydLGGE1mDfKRA',
#    'alias': 'guru-kitchen-bar-edmonton',
#    'name': 'GURU Kitchen + Bar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/j9e4UpwAlZwIzBqD8if3NQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/guru-kitchen-bar-edmonton?adjust_creative=DUaZ2NSU0hA5L7xLRZNoXA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DUaZ2NSU0hA5L7xLRZNoXA',
#    'review_count': 10,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'}],
#    'rating': 4.4,
#    'coordinates': {'latitude': 53.5456285, 'longitude': -113.4946715},
#    'transactions': [],
#    'location': {'address1': '108-10111 104 Avenue',
#     'address2': '',
#     'address3': '',
#     'city': 'Edmonton',
#     'zip_code': 'T5J 0J4',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['108-10111 104 Avenue',
#      'Edmonton, AB T5J 0J4',
#      'Canada']},
#    'phone': '+17807578861',
#    'display_phone': '+1 780-757-8861',
#    'distance': 1395.6763404789588,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'n4z30-wLC1WYW6SDSDAdRA',
#    'alias': 'bianco-edmonton',
#    'name': 'Bianco',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/nhS9MVJqfO1-GDm9Hvl1KQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bianco-edmonton?adjust_creative=DUaZ2NSU0hA5L7xLRZNoXA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DUaZ2NSU0hA5L7xLRZNoXA',
#    'review_count': 58,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 53.5424557443708,
#     'longitude': -113.49200528115},
#    'transactions': [],
#    'location': {'address1': '120-10020 101 A Avenue',
#     'address2': '',
#     'address3': None,
#     'city': 'Edmonton',
#     'zip_code': 'T5J 3G2',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['120-10020 101 A Avenue',
#      'Edmonton, AB T5J 3G2',
#      'Canada']},
#    'phone': '+17807618838',
#    'display_phone': '+1 780-761-8838',
#    'distance': 1789.8655804567045,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'ikLU2L-MPsoNBDYazISQsQ',
#    'alias': 'triple-os-edmonton',
#    'name': "Triple O's",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/u88oWsGS7sLxnKzKQSLBcA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/triple-os-edmonton?adjust_creative=DUaZ2NSU0hA5L7xLRZNoXA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DUaZ2NSU0hA5L7xLRZNoXA',
#    'review_count': 1,
#    'categories': [{'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 53.5559766, 'longitude': -113.496479},
#    'transactions': [],
#    'location': {'address1': '10240 Kingsway NW',
#     'address2': '',
#     'address3': None,
#     'city': 'Edmonton',
#     'zip_code': 'T5H 3V9',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['10240 Kingsway NW',
#      'Edmonton, AB T5H 3V9',
#      'Canada']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 460.2067419882692,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'YSmh3UwoCPzoLytbYKYBLw',
#    'alias': 'barbecue-king-city-edmonton',
#    'name': 'Barbecue King City',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/jM-_hXioEwbD2byMVECrDQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/barbecue-king-city-edmonton?adjust_creative=DUaZ2NSU0hA5L7xLRZNoXA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DUaZ2NSU0hA5L7xLRZNoXA',
#    'review_count': 6,
#    'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#     {'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 53.550455, 'longitude': -113.489228},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '10606 - 97 Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Edmonton',
#     'zip_code': 'T5H 2L6',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['10606 - 97 Street',
#      'Edmonton, AB T5H 2L6',
#      'Canada']},
#    'phone': '+17804282211',
#    'display_phone': '+1 780-428-2211',
#    'distance': 1194.2394293398645,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'https://barbequekingcity.com/menu/',
#     'open24_hours': None,
#     'waitlist_reservation': None}}],
#  'total': 746,
#  'region': {'center': {'longitude': -113.50353240966797,
#    'latitude': 53.55702283002651}}}

# %%
import requests

api_key = 'HsjVUPuTRB5PlCIuRhiLiYPKh8_k8amo-x0rusX8hTelwqfHt1U75dH5smT5gA5K5NP5ZWL-_J0PL-URfKQ3KB_5dpLIgtUI-d_E13sjjpz-1ldcetFvm7cf2NUZZnYx'

headers_low = {
    'Authorization': f'Bearer {api_key}',
}
for address_low in address_list_low100:
  params_low = {
    'term': 'restaurants',
    'location': address_low,
    'radius': 4000
  }

# %%
response = requests.get("https://api.yelp.com/v3/businesses/search", headers=headers_low, params=params_low)
Yelp_data_low = response.json()
Yelp_data_low
# Out:
# {'businesses': [{'id': 'sVwbevTHJK6SmZxBIHzm5g',
#    'alias': 'campiō-brewing-co-edmonton',
#    'name': 'Campiō Brewing Co',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RhK0KAWH1gGVCgpcm3eP_w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/campi%C5%8D-brewing-co-edmonton?adjust_creative=DUaZ2NSU0hA5L7xLRZNoXA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DUaZ2NSU0hA5L7xLRZNoXA',
#    'review_count': 48,
#    'categories': [{'alias': 'tradamerican', 'title': 'American'},
#     {'alias': 'breweries', 'title': 'Breweries'}],
#    'rating': 4.3,
#    'coordinates': {'latitude': 53.54431, 'longitude': -113.5007},
#    'transactions': [],
#    'location': {'address1': '10257 105 Street NW',
#     'address2': '',
#     'address3': None,
#     'city': 'Edmonton',
#     'zip_code': 'T5J 1E3',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['10257 105 Street NW',
#      'Edmonton, AB T5J 1E3',
#      'Canada']},
#    'phone': '+15876351952',
#    'display_phone': '+1 587-635-1952',
#    'distance': 1425.9308491167137,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': '3koeM2Blt-4rEmVIJAZf8Q',
#    'alias': 'woodwork-edmonton',
#    'name': 'Woodwork',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/XHIpmhR3bR6RuSfIXoqnMQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/woodwork-edmonton?adjust_creative=DUaZ2NSU0hA5L7xLRZNoXA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DUaZ2NSU0hA5L7xLRZNoXA',
#    'review_count': 175,
#    'categories': [{'alias': 'newcanadian', 'title': 'Canadian (New)'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.2,
#    'coordinates': {'latitude': 53.5419431693898,
#     'longitude': -113.490731079867},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '10132-100 Street',
#     'address2': None,
#     'address3': '',
#     'city': 'Edmonton',
#     'zip_code': 'T5J 0N8',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['10132-100 Street', 'Edmonton, AB T5J 0N8', 'Canada']},
#    'phone': '+17807574100',
#    'display_phone': '+1 780-757-4100',
#    'distance': 1877.9805173078248,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'http://woodworkyeg.com/menus/',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': '36F6K3PGGV2ICZBNDoh0wg',
#    'alias': 'baijiu-edmonton',
#    'name': 'Baijiu',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/GlJ1I-FBRASUV26yqDbQqg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/baijiu-edmonton?adjust_creative=DUaZ2NSU0hA5L7xLRZNoXA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DUaZ2NSU0hA5L7xLRZNoXA',
#    'review_count': 57,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.4,
#    'coordinates': {'latitude': 53.5459076, 'longitude': -113.4990951},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '103-10359 104 Street NW',
#     'address2': None,
#     'address3': '',
#     'city': 'Edmonton',
#     'zip_code': 'T5J 1B9',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['103-10359 104 Street NW',
#      'Edmonton, AB T5J 1B9',
#      'Canada']},
#    'phone': '+17804217060',
#    'display_phone': '+1 780-421-7060',
#    'distance': 1276.3258686052727,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'ZSh2zcBZfp7o9llcFQCdwQ',
#    'alias': 'restaurant-yarrow-edmonton-2',
#    'name': 'Restaurant Yarrow',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/RaYqOA0OQvPmF1i_tVGXIA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/restaurant-yarrow-edmonton-2?adjust_creative=DUaZ2NSU0hA5L7xLRZNoXA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DUaZ2NSU0hA5L7xLRZNoXA',
#    'review_count': 9,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'newcanadian', 'title': 'Canadian (New)'}],
#    'rating': 4.8,
#    'coordinates': {'latitude': 53.548848, 'longitude': -113.517936},
#    'transactions': [],
#    'location': {'address1': '101-10544 114 Street NW',
#     'address2': None,
#     'address3': '',
#     'city': 'Edmonton',
#     'zip_code': 'T5H 3J7',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['101-10544 114 Street NW',
#      'Edmonton, AB T5H 3J7',
#      'Canada']},
#    'phone': '+15878818282',
#    'display_phone': '+1 587-881-8282',
#    'distance': 1315.900595677952,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'gtXAx_G5j6K1TmuJ2v5Rbg',
#    'alias': 'rge-rd-edmonton',
#    'name': 'RGE RD',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Br_RNNJuBFsjMiDqaWt3LA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rge-rd-edmonton?adjust_creative=DUaZ2NSU0hA5L7xLRZNoXA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DUaZ2NSU0hA5L7xLRZNoXA',
#    'review_count': 179,
#    'categories': [{'alias': 'newcanadian', 'title': 'Canadian (New)'}],
#    'rating': 4.4,
#    'coordinates': {'latitude': 53.5507814, 'longitude': -113.5338044},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '10643 - 123 Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Edmonton',
#     'zip_code': 'T5M 1Z1',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['10643 - 123 Street',
#      'Edmonton, AB T5M 1Z1',
#      'Canada']},
#    'phone': '+17804474577',
#    'display_phone': '+1 780-447-4577',
#    'distance': 2116.6893460461592,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'l7DhJNwumsbDK9cuusE9sQ',
#    'alias': 'bundok-edmonton-3',
#    'name': 'Bundok',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/39692OqhRjCeWhdCFwfssA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bundok-edmonton-3?adjust_creative=DUaZ2NSU0hA5L7xLRZNoXA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DUaZ2NSU0hA5L7xLRZNoXA',
#    'review_count': 55,
#    'categories': [{'alias': 'newcanadian', 'title': 'Canadian (New)'}],
#    'rating': 4.4,
#    'coordinates': {'latitude': 53.54366, 'longitude': -113.4994049},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '10228 104 Street NW',
#     'address2': '',
#     'address3': None,
#     'city': 'Edmonton',
#     'zip_code': 'T5J 1B8',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['10228 104 Street NW',
#      'Edmonton, AB T5J 1B8',
#      'Canada']},
#    'phone': '+17804200192',
#    'display_phone': '+1 780-420-0192',
#    'distance': 1505.373097767792,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': '00uLQHBVirvmfv4pGlIBGA',
#    'alias': 'baobao-edmonton',
#    'name': 'BaoBao',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/wuzlhZq75S-Yb9aartvWUQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/baobao-edmonton?adjust_creative=DUaZ2NSU0hA5L7xLRZNoXA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DUaZ2NSU0hA5L7xLRZNoXA',
#    'review_count': 43,
#    'categories': [{'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'dumplings', 'title': 'Dumplings'}],
#    'rating': 4.3,
#    'coordinates': {'latitude': 53.54136, 'longitude': -113.50214},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '10544 Jasper Avenue',
#     'address2': '',
#     'address3': '',
#     'city': 'Edmonton',
#     'zip_code': 'T5J 1Z7',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['10544 Jasper Avenue',
#      'Edmonton, AB T5J 1Z7',
#      'Canada']},
#    'phone': '+15875235747',
#    'display_phone': '+1 587-523-5747',
#    'distance': 1743.927973615149,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'https://baobaoedmonton.com/menu/',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'lPPYZr1_jx0XeW-xR9WJtw',
#    'alias': 'dosc-edmonton',
#    'name': 'DOSC',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/d08xhGLEgbd_5Vw13ZhBXA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dosc-edmonton?adjust_creative=DUaZ2NSU0hA5L7xLRZNoXA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DUaZ2NSU0hA5L7xLRZNoXA',
#    'review_count': 119,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 53.5428720872819,
#     'longitude': -113.499512283622},
#    'transactions': [],
#    'location': {'address1': '10190 - 104 Street NW',
#     'address2': 'Main Floor',
#     'address3': None,
#     'city': 'Edmonton',
#     'zip_code': 'T5J 1A7',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['10190 - 104 Street NW',
#      'Main Floor',
#      'Edmonton, AB T5J 1A7',
#      'Canada']},
#    'phone': '+17805400606',
#    'display_phone': '+1 780-540-0606',
#    'distance': 1595.744946892782,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'http://www.dosc.ca/menu',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'HQYPKYnuVphFs1tDpuVmZw',
#    'alias': 'hus-noodle-nook-edmonton',
#    'name': "Hu's Noodle Nook",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RddBpDPoWrJ_wF8E63gtCQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hus-noodle-nook-edmonton?adjust_creative=DUaZ2NSU0hA5L7xLRZNoXA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DUaZ2NSU0hA5L7xLRZNoXA',
#    'review_count': 2,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 53.546913, 'longitude': -113.515102},
#    'transactions': [],
#    'location': {'address1': '11238 104 Avenue NW',
#     'address2': '',
#     'address3': None,
#     'city': 'Edmonton',
#     'zip_code': 'T5K 2X4',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['11238 104 Avenue NW',
#      'Edmonton, AB T5K 2X4',
#      'Canada']},
#    'phone': '+17802502600',
#    'display_phone': '+1 780-250-2600',
#    'distance': 1359.3651460834205,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'http://husnoodlenook.ca/Ramen.html',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'PyRlDfJC81G57YDNr9Nc5Q',
#    'alias': 'sodo-on-jasper-edmonton',
#    'name': 'SoDo on Jasper',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/bO9zhNEnEDercrJuoMBcIQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sodo-on-jasper-edmonton?adjust_creative=DUaZ2NSU0hA5L7xLRZNoXA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DUaZ2NSU0hA5L7xLRZNoXA',
#    'review_count': 9,
#    'categories': [{'alias': 'tradamerican', 'title': 'American'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.8,
#    'coordinates': {'latitude': 53.5407042, 'longitude': -113.5109845},
#    'transactions': [],
#    'location': {'address1': '11011 Jasper Avenue',
#     'address2': '',
#     'address3': None,
#     'city': 'Edmonton',
#     'zip_code': 'T5K 0K6',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['11011 Jasper Avenue',
#      'Edmonton, AB T5K 0K6',
#      'Canada']},
#    'phone': '+17807051101',
#    'display_phone': '+1 780-705-1101',
#    'distance': 1880.1492497557917,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'https://www.sodoyeg.com/menu',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'ivpULDSBS4mP3mJqmziKQw',
#    'alias': 'cafe-amore-bistro-edmonton-3',
#    'name': 'Cafe Amore Bistro',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/z6lhB60i8EQsVjUU3AWnsg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-amore-bistro-edmonton-3?adjust_creative=DUaZ2NSU0hA5L7xLRZNoXA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DUaZ2NSU0hA5L7xLRZNoXA',
#    'review_count': 150,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.3,
#    'coordinates': {'latitude': 53.5496883, 'longitude': -113.5068932},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '10807 106 Avenue NW',
#     'address2': '',
#     'address3': '',
#     'city': 'Edmonton',
#     'zip_code': 'T5H 4A7',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['10807 106 Avenue NW',
#      'Edmonton, AB T5H 4A7',
#      'Canada']},
#    'phone': '+17804777896',
#    'display_phone': '+1 780-477-7896',
#    'distance': 845.2383177047267,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'Z2gGsSqf9KknTvMGp1yByw',
#    'alias': 'moxies-edmonton-2',
#    'name': 'Moxies',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/vEC6aSnBDNxPhXr3Gkgp1g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/moxies-edmonton-2?adjust_creative=DUaZ2NSU0hA5L7xLRZNoXA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DUaZ2NSU0hA5L7xLRZNoXA',
#    'review_count': 49,
#    'categories': [{'alias': 'newcanadian', 'title': 'Canadian (New)'},
#     {'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'lounges', 'title': 'Lounges'}],
#    'rating': 3.2,
#    'coordinates': {'latitude': 53.559431, 'longitude': -113.5046145},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '10628 Kingsway Avenue',
#     'address2': '',
#     'address3': '',
#     'city': 'Edmonton',
#     'zip_code': 'T5G 0W8',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['10628 Kingsway Avenue',
#      'Edmonton, AB T5G 0W8',
#      'Canada']},
#    'phone': '+17809440232',
#    'display_phone': '+1 780-944-0232',
#    'distance': 252.7920213566803,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': '',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'n4z30-wLC1WYW6SDSDAdRA',
#    'alias': 'bianco-edmonton',
#    'name': 'Bianco',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/nhS9MVJqfO1-GDm9Hvl1KQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bianco-edmonton?adjust_creative=DUaZ2NSU0hA5L7xLRZNoXA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DUaZ2NSU0hA5L7xLRZNoXA',
#    'review_count': 58,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 53.5424557443708,
#     'longitude': -113.49200528115},
#    'transactions': [],
#    'location': {'address1': '120-10020 101 A Avenue',
#     'address2': '',
#     'address3': None,
#     'city': 'Edmonton',
#     'zip_code': 'T5J 3G2',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['120-10020 101 A Avenue',
#      'Edmonton, AB T5J 3G2',
#      'Canada']},
#    'phone': '+17807618838',
#    'display_phone': '+1 780-761-8838',
#    'distance': 1789.8655804567045,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': '9hQNxW2PrqLq5tVciT3OnQ',
#    'alias': 'bangkok-restaurant-edmonton',
#    'name': 'Bangkok Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9MD8d4Z2i-12m9GZp6QkYA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bangkok-restaurant-edmonton?adjust_creative=DUaZ2NSU0hA5L7xLRZNoXA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DUaZ2NSU0hA5L7xLRZNoXA',
#    'review_count': 24,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'hotpot', 'title': 'Hot Pot'}],
#    'rating': 4.1,
#    'coordinates': {'latitude': 53.5611, 'longitude': -113.52032},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '11476 112 Ave NW',
#     'address2': '',
#     'address3': '',
#     'city': 'Edmonton',
#     'zip_code': 'T5G 0H6',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['11476 112 Ave NW', 'Edmonton, AB T5G 0H6', 'Canada']},
#    'phone': '+17804140430',
#    'display_phone': '+1 780-414-0430',
#    'distance': 1193.3634708686761,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'fdez0D4ovth2k1IvR0ZbpQ',
#    'alias': 'sabor-edmonton',
#    'name': 'Sabor',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/OTkw-L-93zoKsAqn8GNT_w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sabor-edmonton?adjust_creative=DUaZ2NSU0hA5L7xLRZNoXA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DUaZ2NSU0hA5L7xLRZNoXA',
#    'review_count': 186,
#    'categories': [{'alias': 'portuguese', 'title': 'Portuguese'},
#     {'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 4.3,
#    'coordinates': {'latitude': 53.543381087231,
#     'longitude': -113.497605148344},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '10220 103 Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Edmonton',
#     'zip_code': 'T5J 4A1',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['10220 103 Street', 'Edmonton, AB T5J 4A1', 'Canada']},
#    'phone': '+17807571114',
#    'display_phone': '+1 780-757-1114',
#    'distance': 1566.6162640061495,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': '-jqZKflff1oagRdl2eTg5Q',
#    'alias': 'ashford-house-pub-and-kitchen-edmonton',
#    'name': 'Ashford House Pub & Kitchen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/mAUoOKzvEQgcAJGeAcfZwQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ashford-house-pub-and-kitchen-edmonton?adjust_creative=DUaZ2NSU0hA5L7xLRZNoXA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DUaZ2NSU0hA5L7xLRZNoXA',
#    'review_count': 4,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'irish_pubs', 'title': 'Irish Pub'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 53.5514782, 'longitude': -113.5298359},
#    'transactions': [],
#    'location': {'address1': '12026 107 Avenue NW',
#     'address2': '',
#     'address3': None,
#     'city': 'Edmonton',
#     'zip_code': 'T5H 0Z2',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['12026 107 Avenue NW',
#      'Edmonton, AB T5H 0Z2',
#      'Canada']},
#    'phone': '+15874003204',
#    'display_phone': '+1 587-400-3204',
#    'distance': 1843.848074015876,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': '0z6gFGDSeb59ZkoSoO7LdQ',
#    'alias': 'otto-food-and-drink-edmonton',
#    'name': 'Otto Food and Drink',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ZzCbWulEufj22KpEL8l4OQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/otto-food-and-drink-edmonton?adjust_creative=DUaZ2NSU0hA5L7xLRZNoXA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DUaZ2NSU0hA5L7xLRZNoXA',
#    'review_count': 79,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.6,
#    'coordinates': {'latitude': 53.56448, 'longitude': -113.48682},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '11405 95 Street NW',
#     'address2': '',
#     'address3': None,
#     'city': 'Edmonton',
#     'zip_code': 'T5G 1L3',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['11405 95 Street NW',
#      'Edmonton, AB T5G 1L3',
#      'Canada']},
#    'phone': '+17804776244',
#    'display_phone': '+1 780-477-6244',
#    'distance': 1373.2284061818998,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'LDPrW1OI0YA2ppITnbUFng',
#    'alias': 'rosewood-foods-edmonton',
#    'name': 'Rosewood Foods',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/IWNZpe5gibwA-1rmbrcs1w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rosewood-foods-edmonton?adjust_creative=DUaZ2NSU0hA5L7xLRZNoXA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DUaZ2NSU0hA5L7xLRZNoXA',
#    'review_count': 19,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 4.6,
#    'coordinates': {'latitude': 53.5424329438608, 'longitude': -113.4909425},
#    'transactions': [],
#    'location': {'address1': '101-10150 100 Street NW',
#     'address2': '',
#     'address3': None,
#     'city': 'Edmonton',
#     'zip_code': 'T5J 0P6',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['101-10150 100 Street NW',
#      'Edmonton, AB T5J 0P6',
#      'Canada']},
#    'phone': '+17807578030',
#    'display_phone': '+1 780-757-8030',
#    'distance': 1823.1026581926553,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'qoD6-nDDfEuNPRJipJxpOA',
#    'alias': 'oeb-breakfast-edmonton-4',
#    'name': 'OEB Breakfast',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/OAwa2JhwInGmkEBXRMzUfw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/oeb-breakfast-edmonton-4?adjust_creative=DUaZ2NSU0hA5L7xLRZNoXA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DUaZ2NSU0hA5L7xLRZNoXA',
#    'review_count': 250,
#    'categories': [{'alias': 'breakfast_brunch',
#      'title': 'Breakfast & Brunch'}],
#    'rating': 4.4,
#    'coordinates': {'latitude': 53.542609, 'longitude': -113.492594},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '10174 100A Street',
#     'address2': None,
#     'address3': '',
#     'city': 'Edmonton',
#     'zip_code': 'T5J 0H3',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['10174 100A Street',
#      'Edmonton, AB T5J 0H3',
#      'Canada']},
#    'phone': '+15875200936',
#    'display_phone': '+1 587-520-0936',
#    'distance': 1757.6266106823377,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'http://eatoeb.com/menu/',
#     'open24_hours': None,
#     'waitlist_reservation': True}},
#   {'id': '2f9zoxMg6hmonYNR6zxBDw',
#    'alias': 'dogpatch-edmonton',
#    'name': 'Dogpatch',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/1LxwG3RbreNbLMMtHHgyZg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dogpatch-edmonton?adjust_creative=DUaZ2NSU0hA5L7xLRZNoXA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DUaZ2NSU0hA5L7xLRZNoXA',
#    'review_count': 26,
#    'categories': [{'alias': 'bistros', 'title': 'Bistros'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 53.54468327770364,
#     'longitude': -113.47114641219376},
#    'transactions': [],
#    'location': {'address1': '10158 90 Street NW',
#     'address2': '',
#     'address3': None,
#     'city': 'Edmonton',
#     'zip_code': 'T5H 1R7',
#     'country': 'CA',
#     'state': 'AB',
#     'display_address': ['10158 90 Street NW',
#      'Edmonton, AB T5H 1R7',
#      'Canada']},
#    'phone': '+17807618700',
#    'display_phone': '+1 780-761-8700',
#    'distance': 2541.655177286034,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'http://dogpatchyeg.ca/#menu',
#     'open24_hours': None,
#     'waitlist_reservation': None}}],
#  'total': 746,
#  'region': {'center': {'longitude': -113.50353240966797,
#    'latitude': 53.55702283002651}}}

# %%
# Transform to pandas Dataframe
from pyspark.sql import SparkSession
from pyspark.sql.types import StringType

df_yelp_top = pd.DataFrame(Yelp_data_top["businesses"])
restaurant_name = df_yelp_top['name']

#Create PySpark DataFrame from Pandas
df_yelp_top_spark = spark.createDataFrame(restaurant_name, StringType()).toDF("Restaurant_Name_Top")

#Creat a spark table based on the pySpark dataframe
df_yelp_top_spark.createOrReplaceTempView("df_yelp_top")

spark.sql("SELECT * FROM df_yelp_top ORDER BY Restaurant_Name_Top").show()
# Out:
# +--------------------+
# | Restaurant_Name_Top|
# +--------------------+
# |Browns Socialhous...|
# |           Caffrey's|
# |   Chef's Temptation|
# |       China Kitchen|
# |       China Kitchen|
# | Earls Kitchen + Bar|
# |       Everyday Food|
# |Fat Fox Nashville...|
# |           Five Guys|
# |Golden Capital Re...|
# |             Kobachi|
# |      Lahore In Town|
# |Original Joe's Re...|
# |Rau Vietnamese Ki...|
# |Ricky's All Day G...|
# |             Sawmill|
# |      The Big Squish|
# |   The Purple Perogy|
# |           Wing Snob|
# |Yoshi Japanese Re...|
# +--------------------+

# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import StringType

# Transform to pandas Dataframe
df_yelp_low = pd.DataFrame(Yelp_data_low["businesses"])
restaurant_name_low = df_yelp_low['name']

#Create PySpark DataFrame from Pandas
df_yelp_low_spark = spark.createDataFrame(restaurant_name_low, StringType()).toDF("Restaurant_Name_low")

#Creat a spark table based on the pySpark dataframe
df_yelp_low_spark.createOrReplaceTempView("df_yelp_low")

spark.sql("SELECT * FROM df_yelp_low ORDER BY Restaurant_Name_low").show()
# Out:
# +--------------------+
# | Restaurant_Name_low|
# +--------------------+
# |Ashford House Pub...|
# |              Baijiu|
# |  Bangkok Restaurant|
# |              BaoBao|
# |              Bianco|
# |              Bundok|
# |   Cafe Amore Bistro|
# |   Campiō Brewing Co|
# |                DOSC|
# |            Dogpatch|
# |    Hu's Noodle Nook|
# |              Moxies|
# |       OEB Breakfast|
# | Otto Food and Drink|
# |              RGE RD|
# |   Restaurant Yarrow|
# |      Rosewood Foods|
# |               Sabor|
# |      SoDo on Jasper|
# |            Woodwork|
# +--------------------+

# %% [markdown]
# # Perform a data exploration analysis to try to explain the relationship, if any, between the top/bottom 100 listings and the nearby restaurants. Feel free to create new tables, dataframes, or whatever else you deem necessary for your analysis.

# %%
# Transform to pandas Dataframe
df_yelp_low = pd.DataFrame(Yelp_data_low["businesses"])
restaurant_name_low = df_yelp_low['name']
rating_low = df_yelp_low['rating']

#Create PySpark DataFrame from Pandas
df_yelp_low_spark = spark.createDataFrame(zip(restaurant_name_low, rating_low), schema=["Restaurant_Name", "Rating"])

#Creat a spark table based on the pySpark dataframe
df_yelp_low_spark.createOrReplaceTempView("df_yelp_low")
spark.sql("SELECT * FROM df_yelp_low ORDER BY Rating DESC").show()
spark.sql("SELECT Rating, COUNT(*) AS COUNT_LOW FROM df_yelp_low Group BY Rating ORDER BY Rating DESC").show()
spark.sql("SELECT AVG(Rating) AS Avg_Rating_Low FROM df_yelp_low").show()
# Out:
# +--------------------+------+
# |     Restaurant_Name|Rating|
# +--------------------+------+
# |    Hu's Noodle Nook|   5.0|
# |Ashford House Pub...|   5.0|
# |   Restaurant Yarrow|   4.8|
# |      SoDo on Jasper|   4.8|
# | Otto Food and Drink|   4.6|
# |      Rosewood Foods|   4.6|
# |            Dogpatch|   4.5|
# |              Baijiu|   4.4|
# |       OEB Breakfast|   4.4|
# |              RGE RD|   4.4|
# |              Bundok|   4.4|
# |   Cafe Amore Bistro|   4.3|
# |   Campiō Brewing Co|   4.3|
# |               Sabor|   4.3|
# |              BaoBao|   4.3|
# |            Woodwork|   4.2|
# |  Bangkok Restaurant|   4.1|
# |                DOSC|   4.0|
# |              Bianco|   4.0|
# |              Moxies|   3.2|
# +--------------------+------+
#
# +------+---------+
# |Rating|COUNT_LOW|
# +------+---------+
# |   5.0|        2|
# |   4.8|        2|
# |   4.6|        2|
# |   4.5|        1|
# |   4.4|        4|
# |   4.3|        4|
# |   4.2|        1|
# |   4.1|        1|
# |   4.0|        2|
# |   3.2|        1|
# +------+---------+
#
# +--------------+
# |Avg_Rating_Low|
# +--------------+
# |          4.38|
# +--------------+

# %%
# Transform to pandas Dataframe
df_yelp_top = pd.DataFrame(Yelp_data_top["businesses"])
restaurant_name_top = df_yelp_top['name']
rating_top = df_yelp_top['rating']

#Create PySpark DataFrame from Pandas
df_yelp_top_spark = spark.createDataFrame(zip(restaurant_name_top, rating_top), schema=["Restaurant_Name", "Rating"])

#Creat a spark table based on the pySpark dataframe
df_yelp_top_spark.createOrReplaceTempView("df_yelp_top")
spark.sql("SELECT * FROM df_yelp_top ORDER BY Rating DESC").show()
spark.sql("SELECT Rating, COUNT(*) AS COUNT_TOP FROM df_yelp_top Group BY Rating ORDER BY Rating DESC").show()
spark.sql("SELECT AVG(Rating) AS Avg_Rating_Top FROM df_yelp_top").show()
# Out:
# +--------------------+------+
# |     Restaurant_Name|Rating|
# +--------------------+------+
# |      The Big Squish|   5.0|
# |      Lahore In Town|   5.0|
# |             Kobachi|   4.8|
# |   The Purple Perogy|   4.5|
# |       Everyday Food|   4.5|
# |   Chef's Temptation|   4.2|
# |           Five Guys|   4.0|
# |Original Joe's Re...|   3.9|
# |Yoshi Japanese Re...|   3.8|
# |           Caffrey's|   3.6|
# |           Wing Snob|   3.5|
# |Browns Socialhous...|   3.4|
# |Golden Capital Re...|   3.4|
# | Earls Kitchen + Bar|   3.4|
# |       China Kitchen|   3.4|
# |       China Kitchen|   3.0|
# |Ricky's All Day G...|   2.8|
# |             Sawmill|   2.6|
# |Fat Fox Nashville...|   1.0|
# |Rau Vietnamese Ki...|   0.0|
# +--------------------+------+
#
# +------+---------+
# |Rating|COUNT_TOP|
# +------+---------+
# |   5.0|        2|
# |   4.8|        1|
# |   4.5|        2|
# |   4.2|        1|
# |   4.0|        1|
# |   3.9|        1|
# |   3.8|        1|
# |   3.6|        1|
# |   3.5|        1|
# |   3.4|        4|
# |   3.0|        1|
# |   2.8|        1|
# |   2.6|        1|
# |   1.0|        1|
# |   0.0|        1|
# +------+---------+
#
# +------------------+
# |    Avg_Rating_Top|
# +------------------+
# |3.4899999999999998|
# +------------------+
